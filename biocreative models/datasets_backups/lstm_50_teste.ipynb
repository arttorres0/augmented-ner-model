# %% [markdown]
# Adapted from [ner_with_bilstm_and_crf](https://www.kaggle.com/nikkisharma536/ner-with-bilstm-and-crf/notebook)
# Altigran Soares da Silva
# IComp/UFAM - 15/03/2021

# %%
# Import libs
# Also remember to use GPU in your colab notebook
# %tensorflow_version 1.x

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

import math
from math import nan
import random
import json
from future.utils import iteritems
import pickle
from requests import get

# Needed for using CRF
# !pip install git+https://www.github.com/keras-team/keras-contrib.git

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from keras.models import Model, Input
from keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional
import keras as k
from keras_contrib.layers import CRF
from keras.callbacks import ModelCheckpoint, EarlyStopping
import matplotlib.pyplot as plt

# !pip install seqeval
from seqeval.metrics import f1_score, classification_report
# Out:
# TensorFlow 1.x selected.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://www.github.com/keras-team/keras-contrib.git
#   Cloning https://www.github.com/keras-team/keras-contrib.git to /tmp/pip-req-build-qx538xkw
#   Running command git clone -q https://www.github.com/keras-team/keras-contrib.git /tmp/pip-req-build-qx538xkw
# Requirement already satisfied: keras in /tensorflow-1.15.2/python3.7 (from keras-contrib==2.0.8) (2.3.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras->keras-contrib==2.0.8) (3.1.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /tensorflow-1.15.2/python3.7 (from keras->keras-contrib==2.0.8) (1.0.8)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from keras->keras-contrib==2.0.8) (1.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from keras->keras-contrib==2.0.8) (3.13)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras->keras-contrib==2.0.8) (1.21.6)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from keras->keras-contrib==2.0.8) (1.15.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from keras->keras-contrib==2.0.8) (1.1.2)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras->keras-contrib==2.0.8) (1.5.2)
# Building wheels for collected packages: keras-contrib
#   Building wheel for keras-contrib (setup.py) ... done
#   Created wheel for keras-contrib: filename=keras_contrib-2.0.8-py3-none-any.whl size=101077 sha256=ea32d95d5c56fea4d95e92fb651396ccb698f5134ddb49025a8f8c5450971b49
#   Stored in directory: /tmp/pip-ephem-wheel-cache-73z75wky/wheels/bb/1f/f2/b57495012683b6b20bbae94a3915ec79753111452d79886abc
# Successfully built keras-contrib
# Installing collected packages: keras-contrib
# Successfully installed keras-contrib-2.0.8
# Using TensorFlow backend.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 1.6 MB/s
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from seqeval) (1.21.6)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.7/dist-packages (from seqeval) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval) (3.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.1.0)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=3be92e513947437e99a1531f554e262270b7be91e5784aacf9ebe485ab4ecf56
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
# Successfully built seqeval
# Installing collected packages: seqeval
# Successfully installed seqeval-1.2.2

# %%
# Code to read csv file from google drive into Colaboratory:
DATA_TRAINING_FILE_ID = '1iTLWWB9aFjtjVz7Kq4ku2syjhINCz2_q'
DATA_TRAINING_FILENAME = 'ner_medical_training.csv'
DATA_DEV_FILE_ID = '1fB1Mp-6_zxGC3NO5sMX23B-LPyYzc9I9'
DATA_DEV_FILENAME = 'ner_medical_dev.csv'
DATA_TEST_FILE_ID = '17vmu2VXPwvOKuQ66kDY7t38dFqkYccvx'
DATA_TEST_FILENAME = 'ner_medical_test.csv'
BACKUP_FOLDER_ID = '1EwDUGjrtg8AiUhBFAImg5vEUXxYEqQcS'

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
downloaded_training = drive.CreateFile({'id': DATA_TRAINING_FILE_ID})
downloaded_training.GetContentFile(DATA_TRAINING_FILENAME)
downloaded_dev = drive.CreateFile({'id': DATA_DEV_FILE_ID})
downloaded_dev.GetContentFile(DATA_DEV_FILENAME)
downloaded_test = drive.CreateFile({'id': DATA_TEST_FILE_ID})
downloaded_test.GetContentFile(DATA_TEST_FILENAME)

# Read the csv file in a dataframe called "data"
training_data = pd.read_csv(DATA_TRAINING_FILENAME, encoding="latin1")
dev_data = pd.read_csv(DATA_DEV_FILENAME, encoding="latin1")
test_data = pd.read_csv(DATA_TEST_FILENAME, encoding="latin1")
# Fill NaN values using the specified method
# Ffill propagate last valid observation/value forward to next valid 
training_data = training_data.fillna(method="ffill")
dev_data = dev_data.fillna(method="ffill")
test_data = test_data.fillna(method="ffill")

notebook_filename = get('http://172.28.0.2:9000/api/sessions').json()[0]['name']

# %%
# Explore the input dataset
print("Number of training sentences: ", len(training_data.groupby(['Sentence #'])))
print("Number of dev sentences: ", len(dev_data.groupby(['Sentence #'])))
print("Number of test sentences: ", len(test_data.groupby(['Sentence #'])))

training_words = list(set(training_data["Word"].values))
n_training_words = len(training_words)
print("Number of words in the training dataset: ", n_training_words)
dev_words = list(set(dev_data["Word"].values))
n_dev_words = len(dev_words)
print("Number of words in the dev dataset: ", n_dev_words)
test_words = list(set(test_data["Word"].values))
n_test_words = len(test_words)
print("Number of words in the test dataset: ", n_test_words)

training_tags = list(set(training_data["Tag"].values))
print("Tags in the training dataset:", training_tags)
n_training_tags = len(training_tags)
print("Number of Labels in the training dataset: ", n_training_tags)
dev_tags = list(set(dev_data["Tag"].values))
print("Tags in the dev dataset:", dev_tags)
n_dev_tags = len(dev_tags)
print("Number of Labels in the dev dataset: ", n_dev_tags)
test_tags = list(set(test_data["Tag"].values))
print("Tags in the test dataset:", test_tags)
n_test_tags = len(test_tags)
print("Number of Labels in the test dataset: ", n_test_tags)

print("What the training dataset looks like:")
# Show the first 10 rows
training_data.head(n=10)
# Out:
# Number of training sentences:  1000
# Number of dev sentences:  1000
# Number of test sentences:  1000
# Number of words in the training dataset:  10405
# Number of words in the dev dataset:  10246
# Number of words in the test dataset:  10814
# Tags in the training dataset: ['B-Chemical', 'B-Disease', 'I-Disease', 'O', 'I-Chemical']
# Number of Labels in the training dataset:  5
# Tags in the dev dataset: ['B-Chemical', 'B-Disease', 'I-Disease', 'O', 'I-Chemical']
# Number of Labels in the dev dataset:  5
# Tags in the test dataset: ['B-Chemical', 'B-Disease', 'I-Disease', 'O', 'I-Chemical']
# Number of Labels in the test dataset:  5
# What the training dataset looks like:
#     Sentence #              Word         Tag
# 0  Sentence: 1          Naloxone  B-Chemical
# 1  Sentence: 1          reverses           O
# 2  Sentence: 1               the           O
# 3  Sentence: 1  antihypertensive           O
# 4  Sentence: 1            effect           O
# 5  Sentence: 1                of           O
# 6  Sentence: 1         clonidine  B-Chemical
# 7  Sentence: 1                 .           O
# 8  Sentence: 2                In           O
# 9  Sentence: 2    unanesthetized           O

# %%
# SentenceGetter re-organize "data" as an arry of sentences
# Each sentence is a list of pairs <word,tag> 
class SentenceGetter(object):
    
    def __init__(self, dataset):
        self.n_sent = 1
        self.dataset = dataset
        self.empty = False
        agg_func = lambda s: [(w, t) for w,t in zip(s["Word"].values.tolist(),
                                                        s["Tag"].values.tolist())]
        self.grouped = self.dataset.groupby("Sentence #").apply(agg_func)
        self.sentences = [s for s in self.grouped]
    
    def get_next(self):
        try:
            s = self.grouped["Sentence: {}".format(self.n_sent)]
            self.n_sent += 1
            return s
        except:
            return None

training_getter = SentenceGetter(training_data)
training_sentences = training_getter.sentences
dev_getter = SentenceGetter(dev_data)
dev_sentences = dev_getter.sentences
test_getter = SentenceGetter(test_data)
test_sentences = test_getter.sentences

# Example: training sentence #200 
training_sentences[200]
# Out:
# [('Intravenous', 'O'),
#  ('administration', 'O'),
#  ('of', 'O'),
#  ('prochlorperazine', 'B-Chemical'),
#  ('by', 'O'),
#  ('15', 'O'),
#  ('-', 'O'),
#  ('minute', 'O'),
#  ('infusion', 'O'),
#  ('versus', 'O'),
#  ('2', 'O'),
#  ('-', 'O'),
#  ('minute', 'O'),
#  ('bolus', 'O'),
#  ('does', 'O'),
#  ('not', 'O'),
#  ('affect', 'O'),
#  ('the', 'O'),
#  ('incidence', 'O'),
#  ('of', 'O'),
#  ('akathisia', 'B-Disease'),
#  (':', 'O'),
#  ('a', 'O'),
#  ('prospective', 'O'),
#  (',', 'O'),
#  ('randomized', 'O'),
#  (',', 'O'),
#  ('controlled', 'O'),
#  ('trial', 'O'),
#  ('.', 'O')]

# %%
# Explore set of sentences
# Plot sentences by length
import matplotlib.pyplot as plt
plt.hist([len(s) for s in training_sentences], bins=50)
plt.title('Token per training sentence')
plt.xlabel('Len (number of token)')
plt.ylabel('# samples')
plt.show()

# %%
# Explore set of sentences
# Plot sentences by length
import matplotlib.pyplot as plt
plt.hist([len(s) for s in dev_sentences], bins=50)
plt.title('Token per dev sentence')
plt.xlabel('Len (number of token)')
plt.ylabel('# samples')
plt.show()

# %%
# Explore set of sentences
# Plot sentences by length
import matplotlib.pyplot as plt
plt.hist([len(s) for s in test_sentences], bins=50)
plt.title('Token per test sentence')
plt.xlabel('Len (number of token)')
plt.ylabel('# samples')
plt.show()

# %%
# Keras (and most other ML packages) expect all the ids to be numeric, 
# this is an optimisation to save memory. 
# We will create the following dictionaries:
# word2idx: assign a numeric index to each word in the dataset
# idx2word: inverted version of word2idx
# tag2idx: assign a numeric index to each tag in the dataset
# idx2tag: inverted version of tag2idx

# Group training, dev and test data in order to create word-index dicts and to
# convert data to numeric indeces later
data = pd.concat([training_data, dev_data, test_data])

# words <= list of all words in the input dataset
words = list(set(data["Word"].values))
n_words = len(words)

# tags <= list of all tags in the input dataset
tags = []
for tag in set(data["Tag"].values):
    if tag is nan or isinstance(tag, float):
        tags.append('unk')
    else:
        tags.append(tag)
n_tags = len(tags)

# Dictionaries
word2idx = {w: i for i, w in enumerate(words)}
idx2word = {i: w for w, i in iteritems(word2idx)}
tag2idx = {t: i for i, t in enumerate(tags)}
idx2tag = {v: k for k, v in iteritems(tag2idx)}

# Index number for the word 'delirium'
print(word2idx['delirium'])
# Word of index 10
print(idx2word[10])
# Index number for the tag 'B-Chemical'
print(tag2idx['B-Chemical'])
# Tag of index 4
print(idx2tag[4])
# Out:
# 11365
# ineffective
# 0
# I-Chemical

# %%
# Convert train, dev and test data to numeric values
X_train = [[word2idx[w[0]] for w in s] for s in training_sentences]
y_train = [[tag2idx[w[1]] for w in s] for s in training_sentences]

X_dev = [[word2idx[w[0]] for w in s] for s in dev_sentences]
y_dev = [[tag2idx[w[1]] for w in s] for s in dev_sentences]

X_test = [[word2idx[w[0]] for w in s] for s in test_sentences]
y_test = [[tag2idx[w[1]] for w in s] for s in test_sentences]

# %%
# Use this function to randomly remove some points from training dataset
# Use removal percentage in decimal value. E.g.: if you set as 0.5, it will
# remove 50% of the dataset

def random_remove_data_points(dataset, labels, removal_percentage):
    if removal_percentage < 0 or removal_percentage > 1:
        raise Exception("Invalid removal percentage")
    
    if removal_percentage == 1:
        raise Exception("You can't remove the entire dataset")
    
    number_of_points_remaining = math.ceil(len(dataset)*(1-removal_percentage))

    try_again = True

    while try_again:
      random_idxs = np.random.choice(len(dataset), number_of_points_remaining, replace=False)
      cut_dataset_sentences = [dataset[i] for i in random_idxs]
      cut_dataset_labels = [labels[i] for i in random_idxs]
      cut_tags = list(set([idx2tag[j] for sub in cut_dataset_labels for j in sub]))

      if all(i in cut_tags for i in tags if i[:2] == "B-"):
        try_again = False

    return cut_dataset_sentences, cut_dataset_labels 

print(f"Points in X_train before removal: {len(X_train)}")
print(f"Points in y_train before removal: {len(y_train)}")
# X_train, y_train = random_remove_data_points(X_train, y_train, 0.5)
print(f"Points in X_train before removal: {len(X_train)}")
print(f"Points in y_train before removal: {len(y_train)}")
# Out:
# Points in X_train before removal: 1000
# Points in y_train before removal: 1000
# Points in X_train before removal: 1000
# Points in y_train before removal: 1000

# %%
# Aux functions to save data and dicts, if data consistency is important
# and there is desire to not random split again

def save_backup_dataset(dataset, filename):
  dataset_df = pd.DataFrame(dataset)
  dataset_df.to_csv(filename, index=False)
  gfile = drive.CreateFile({'parents': [{'id': BACKUP_FOLDER_ID}]})
  gfile.SetContentFile(filename)
  gfile.Upload()

def save_backup_dict(dict, filename):
  dict_file = open(filename, "wb")
  pickle.dump(dict, dict_file)
  dict_file.close()
  gfile = drive.CreateFile({'parents': [{'id': BACKUP_FOLDER_ID}]})
  gfile.SetContentFile(filename)
  gfile.Upload()

# %%
# Uncomment this cell if you want to save data for further use

# Check some points before saving
print(X_train[0])
print(y_train[0])
print(X_dev[0])
print(y_dev[0])
print(X_test[0])
print(y_test[0])
print(word2idx['delirium'])
print(tag2idx['B-Chemical'])
print(idx2tag[2])
print(idx2word[100])
print(n_words)
print(n_tags)

X_train_filename = f'{notebook_filename}_X_train.csv'
y_train_filename = f'{notebook_filename}_y_train.csv'
X_dev_filename = f'{notebook_filename}_X_dev.csv'
y_dev_filename = f'{notebook_filename}_y_dev.csv'
X_test_filename = f'{notebook_filename}_X_test.csv'
y_test_filename = f'{notebook_filename}_y_test.csv'

word2idx_filename = f'{notebook_filename}_word2idx.pkl'
idx2word_filename = f'{notebook_filename}_idx2word.pkl'
tag2idx_filename = f'{notebook_filename}_tag2idx.pkl'
idx2tag_filename = f'{notebook_filename}_idx2tag.pkl'

others_filename = f'{notebook_filename}_others.pkl'

save_backup_dataset(X_train, X_train_filename)
save_backup_dataset(y_train, y_train_filename)
save_backup_dataset(X_dev, X_dev_filename)
save_backup_dataset(y_dev, y_dev_filename)
save_backup_dataset(X_test, X_test_filename)
save_backup_dataset(y_test, y_test_filename)

save_backup_dict(word2idx, word2idx_filename)
save_backup_dict(idx2word, idx2word_filename)
save_backup_dict(tag2idx, tag2idx_filename)
save_backup_dict(idx2tag, idx2tag_filename)

save_backup_dict({"n_words":n_words, "n_tags":n_tags}, others_filename)
# Out:
# [1268, 1535, 5859, 5133, 80, 7705, 17450, 8849]
# [0, 3, 3, 3, 3, 3, 0, 3]
# [13073, 8129, 5518, 1233, 4230, 2987, 13356, 18316, 5550, 16873, 7811, 8849]
# [1, 2, 2, 3, 0, 4, 1, 3, 3, 3, 3, 3]
# [787, 6172, 16645, 11365, 8849, 509, 7777, 7705, 14085, 16478, 8849]
# [0, 3, 3, 1, 3, 3, 3, 3, 3, 3, 3]
# 11365
# 0
# I-Disease
# expectancy
# 18533
# 5

# %%
# Uncomment this cell if you want to load saved data

# Re-import necessary libs
import pandas as pd
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
import pickle, math
from requests import get
import numpy as np
import matplotlib.pyplot as plt
import random
# %tensorflow_version 1.x
# !pip install git+https://www.github.com/keras-team/keras-contrib.git
from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from keras.models import Model, Input
from keras.layers import CuDNNLSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional
import keras as k
from keras_contrib.layers import CRF
from keras.callbacks import ModelCheckpoint, EarlyStopping
import matplotlib.pyplot as plt
# !pip install seqeval
from seqeval.metrics import f1_score, classification_report

BACKUP_FOLDER_ID = '1EwDUGjrtg8AiUhBFAImg5vEUXxYEqQcS'
notebook_filename = get('http://172.28.0.2:9000/api/sessions').json()[0]['name']

X_train_filename = f'{notebook_filename}_X_train.csv'
y_train_filename = f'{notebook_filename}_y_train.csv'
X_dev_filename = f'{notebook_filename}_X_dev.csv'
y_dev_filename = f'{notebook_filename}_y_dev.csv'
X_test_filename = f'{notebook_filename}_X_test.csv'
y_test_filename = f'{notebook_filename}_y_test.csv'

word2idx_filename = f'{notebook_filename}_word2idx.pkl'
idx2word_filename = f'{notebook_filename}_idx2word.pkl'
tag2idx_filename = f'{notebook_filename}_tag2idx.pkl'
idx2tag_filename = f'{notebook_filename}_idx2tag.pkl'

others_filename = f'{notebook_filename}_others.pkl'

# Re-get important variables
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

def get_backup_files_ids(folder_id):
  file_list = drive.ListFile({'q': "'{}' in parents and trashed=false".format(folder_id)}).GetList()
  return file_list

def load_backup_dataset(file_id):
  downloaded = drive.CreateFile({'id':file_id})
  downloaded.GetContentFile(f"{file_id}.csv")

  dataset = pd.read_csv(f"{file_id}.csv", encoding="latin1")
  dataset = dataset.fillna(method="ffill")
  dataset = dataset.values.tolist()
  dataset = [ [ int(word) for word in sentence if str(word) != 'nan' ] for sentence in dataset]
  return dataset

def load_backup_dict(file_id):
  downloaded = drive.CreateFile({'id':file_id})
  downloaded.GetContentFile(f"{file_id}.pkl")

  dict_file = open(f"{file_id}.pkl", "rb")
  out_dict = pickle.load(dict_file)
  return out_dict

backup_file_list = get_backup_files_ids(BACKUP_FOLDER_ID)

X_train_file_id = [backup_file for backup_file in backup_file_list if backup_file['title'] == X_train_filename][0]['id']
y_train_file_id = [backup_file for backup_file in backup_file_list if backup_file['title'] == y_train_filename][0]['id']
X_dev_file_id = [backup_file for backup_file in backup_file_list if backup_file['title'] == X_dev_filename][0]['id']
y_dev_file_id = [backup_file for backup_file in backup_file_list if backup_file['title'] == y_dev_filename][0]['id']
X_test_file_id = [backup_file for backup_file in backup_file_list if backup_file['title'] == X_test_filename][0]['id']
y_test_file_id = [backup_file for backup_file in backup_file_list if backup_file['title'] == y_test_filename][0]['id']

word2idx_file_id = [backup_file for backup_file in backup_file_list if backup_file['title'] == word2idx_filename][0]['id']
idx2word_file_id = [backup_file for backup_file in backup_file_list if backup_file['title'] == idx2word_filename][0]['id']
tag2idx_file_id = [backup_file for backup_file in backup_file_list if backup_file['title'] == tag2idx_filename][0]['id']
idx2tag_file_id = [backup_file for backup_file in backup_file_list if backup_file['title'] == idx2tag_filename][0]['id']

others_file_id = [backup_file for backup_file in backup_file_list if backup_file['title'] == others_filename][0]['id']

X_train = load_backup_dataset(X_train_file_id)
y_train = load_backup_dataset(y_train_file_id)
X_dev = load_backup_dataset(X_dev_file_id)
y_dev = load_backup_dataset(y_dev_file_id)
X_test = load_backup_dataset(X_test_file_id)
y_test = load_backup_dataset(y_test_file_id)

word2idx = load_backup_dict(word2idx_file_id)
idx2word = load_backup_dict(idx2word_file_id)
tag2idx = load_backup_dict(tag2idx_file_id)
idx2tag = load_backup_dict(idx2tag_file_id)

others = load_backup_dict(others_file_id)

n_words = others["n_words"]
n_tags = others["n_tags"]

# Check some points after loading data to see if they match the ones before saving
print(X_train[0])
print(y_train[0])
print(X_dev[0])
print(y_dev[0])
print(X_test[0])
print(y_test[0])
print(word2idx['delirium'])
print(tag2idx['B-Chemical'])
print(idx2tag[2])
print(idx2word[100])
print(n_words)
print(n_tags)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://www.github.com/keras-team/keras-contrib.git
#   Cloning https://www.github.com/keras-team/keras-contrib.git to /tmp/pip-req-build-c97oxuo9
#   Running command git clone -q https://www.github.com/keras-team/keras-contrib.git /tmp/pip-req-build-c97oxuo9
# Requirement already satisfied: keras in /tensorflow-1.15.2/python3.7 (from keras-contrib==2.0.8) (2.3.1)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras->keras-contrib==2.0.8) (1.21.6)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from keras->keras-contrib==2.0.8) (1.15.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from keras->keras-contrib==2.0.8) (3.13)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from keras->keras-contrib==2.0.8) (1.1.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras->keras-contrib==2.0.8) (3.1.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /tensorflow-1.15.2/python3.7 (from keras->keras-contrib==2.0.8) (1.0.8)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from keras->keras-contrib==2.0.8) (1.4.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras->keras-contrib==2.0.8) (1.5.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: seqeval in /usr/local/lib/python3.7/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from seqeval) (1.21.6)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.7/dist-packages (from seqeval) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval) (3.1.0)
# [1268, 1535, 5859, 5133, 80, 7705, 17450, 8849]
# [0, 3, 3, 3, 3, 3, 0, 3]
# [13073, 8129, 5518, 1233, 4230, 2987, 13356, 18316, 5550, 16873, 7811, 8849]
# [1, 2, 2, 3, 0, 4, 1, 3, 3, 3, 3, 3]
# [787, 6172, 16645, 11365, 8849, 509, 7777, 7705, 14085, 16478, 8849]
# [0, 3, 3, 1, 3, 3, 3, 3, 3, 3, 3]
# 11365
# 0
# I-Disease
# expectancy
# 18533
# 5

# %%
# Aux function to help in augmentation. Generates a dict where entities
# are the keys, and words are the values.

def create_entities_dict(dataset, labels, decoded_word=False):
    entities_dict = {}
    
    for i, sentence in enumerate(dataset):
        for k, word in enumerate(sentence):
            tag = idx2tag[labels[i][k]]
            if tag[:2] == "B-":
                if decoded_word:
                    word_list = [idx2word[word]]
                else:
                    word_list = [word]
                j = k + 1
                if j < len(labels[i]):
                    while idx2tag[labels[i][j]][:2] == "I-":
                        if decoded_word:
                            word_list.append(idx2word[dataset[i][j]])
                        else:
                            word_list.append(dataset[i][j])
                        j = j+1
                        if j == len(labels[i]):
                            break
                        
                if entities_dict.get(tag):
                    if word_list not in entities_dict[tag]:
                        entities_dict[tag].append(word_list)
                else:
                    entities_dict[tag] = [word_list]
                    
    return entities_dict

entities_dict = create_entities_dict(X_train, y_train)

# %%
# Augmentation function using entity replacement technique.
# It will generate a new dataset, with X% more points based on
# the original dataset. E.g.: if you set augmentation percentage as 0.5 and dataset has
# 1000 points, it will generate a dataset with 1500 points.

def generate_sentences(dataset, labels, entities_dict, augmented_set_size_percentage):
    if augmented_set_size_percentage < 0:
        raise Exception("Invalid augmented set size percentage")

    number_of_new_sentences = math.ceil(augmented_set_size_percentage * len(dataset))
    random_idxs = np.random.choice(len(dataset), number_of_new_sentences, replace=True)
    
    base_sequences = [dataset[i] for i in random_idxs]
    base_labels = [labels[i] for i in random_idxs]

    new_sequences = []
    new_labels = []
    
    for k, sequence in enumerate(base_sequences):
        new_sequence = []
        new_label = []

        for i, word in enumerate(sequence):
            tag = idx2tag[base_labels[k][i]]
            if tag == "O":
                new_sequence.append(word)
                new_label.append(base_labels[k][i])
            elif tag[:2] == "B-":
                same_entities_type_tmp = entities_dict[tag]
                same_entities_type = np.array(same_entities_type_tmp, dtype=object)
                random_entity_idx = np.random.choice(len(same_entities_type), 1)[0]
                random_entity = same_entities_type[random_entity_idx]
                random_number_of_tokens = random.randint(1, len(random_entity))
                random_entity_tokens = np.random.choice(random_entity, random_number_of_tokens, replace = False).tolist()
                entity = tag[2:]
                decoded_token_labels = [f"I-{entity}" for token in random_entity_tokens]
                decoded_token_labels[0] = tag
                encoded_token_labels = [tag2idx[label] for label in decoded_token_labels]
                new_sequence = new_sequence + random_entity_tokens
                new_label = new_label + encoded_token_labels

        new_sequences.append(new_sequence)
        new_labels.append(new_label)

    augmented_X_train = dataset + new_sequences
    augmented_y_train = labels + new_labels

    print(f"Points in X_train after augmentation: {len(augmented_X_train)}")
    print(f"Points in y_train after augmentation: {len(augmented_y_train)}")

    return augmented_X_train, augmented_y_train

# %%
# Graph plot function 
plt.style.use('ggplot')

def plot_history(history):
    accuracy = history.history['accuracy']
    val_accuracy = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(accuracy) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(x, accuracy, 'b', label='Training acc')
    plt.plot(x, val_accuracy, 'r', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()
    plt.show()

# %%
# This function converts predicted values to labels from idx2tag
# This is to improve the interpretability of the results
def pred2label(pred):
    out = []
    for pred_i in pred:
        out_i = []
        for p in pred_i:
            p_i = np.argmax(p)
            out_i.append(idx2tag[p_i])
        out.append(out_i)
    return out

# %%
# Model creation function
def create_model(maxlen, n_words):
  input = Input(shape=(maxlen,))
  word_embedding_size = 150

  model = Embedding(input_dim=n_words, output_dim=word_embedding_size, input_length=maxlen)(input)
  model = Bidirectional(LSTM(units=word_embedding_size, 
                           return_sequences=True, 
                           dropout=0.5, 
                           recurrent_dropout=0.5, 
                           kernel_initializer=k.initializers.he_normal()))(model)
  # model = LSTM(units=word_embedding_size * 2, 
  #             return_sequences=True, 
  #             dropout=0.5, 
  #             recurrent_dropout=0.5, 
  #             kernel_initializer=k.initializers.he_normal())(model)
  model = TimeDistributed(Dense(n_tags, activation="relu"))(model)  
  crf = CRF(n_tags)
  out = crf(model)
  model = Model(input, out)

  adam = k.optimizers.Adam(lr=0.0005, beta_1=0.9, beta_2=0.999)
  model.compile(optimizer=adam, loss=crf.loss_function, metrics=[crf.accuracy, 'accuracy'])
  model.summary()

  return model

# %%
# Model training function
def train(model, X_train_df, y_train_df, X_dev_df, y_dev_df):
  filepath="ner-bi-lstm-td-model-{val_accuracy:.2f}.hdf5"
  early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, min_delta=0.0001)
  callbacks_list = [early_stopping]

  history = model.fit(X_train_df, np.array(y_train_df), batch_size=math.ceil(0.05*len(X_train_df)), epochs=100, validation_data=(X_dev_df,  np.array(y_dev_df)), verbose=1, callbacks=callbacks_list)
  plot_history(history)

# %%
# Model testing function
def test(model, X_test_df, y_test_df):
  test_pred = model.predict(X_test_df, verbose=1)   

  pred_labels = pred2label(test_pred)
  test_labels = pred2label(y_test_df)
  
  print("F1-score: {:.1%}".format(f1_score(test_labels, pred_labels)))
  report = classification_report(y_pred=pred_labels, y_true=test_labels, output_dict=True)
  df = pd.DataFrame(report).transpose()
  print("Classification Report:")
  print(df.to_csv())

# %%
def create_train_and_validate_model(augmented_percentage):
  augmented_X_train, augmented_y_train = generate_sentences(X_train, y_train, entities_dict, augmented_percentage)

  # Preparing data for training. 
  # X = observations vector. For text sequence labeling, observations are the index of the words in the sentences
  # y = labels vector. For text sequence labeling, labels are the index of tags in the sentences
  # The BI-LSTM layer expects all texts/sentences to be of the same length. 
  # So, we need to pad shorter sentences
  # We select the padding size to be the length of the longest sentence.

  maxlen_X_train = max([len(s) for s in augmented_X_train])
  maxlen_y_train = max([len(s) for s in augmented_y_train])
  maxlen_X_dev = max([len(s) for s in X_dev])
  maxlen_y_dev = max([len(s) for s in y_dev])
  maxlen_X_test = max([len(s) for s in X_test])
  maxlen_y_test = max([len(s) for s in y_test])

  maxlen = max([maxlen_X_train, maxlen_y_train, maxlen_X_dev, maxlen_y_dev, maxlen_X_test, maxlen_y_test])

  augmented_X_train = pad_sequences(maxlen=maxlen, sequences=augmented_X_train, padding="post",value=n_words - 1)
  new_X_dev = pad_sequences(maxlen=maxlen, sequences=X_dev, padding="post",value=n_words - 1)
  new_X_test = pad_sequences(maxlen=maxlen, sequences=X_test, padding="post",value=n_words - 1)

  augmented_y_train = pad_sequences(maxlen=maxlen, sequences=augmented_y_train, padding="post", value=tag2idx["O"])
  new_y_dev = pad_sequences(maxlen=maxlen, sequences=y_dev, padding="post", value=tag2idx["O"])
  new_y_test = pad_sequences(maxlen=maxlen, sequences=y_test, padding="post", value=tag2idx["O"])

  # Converts vector y (integers) to binary matrix.
  # Each y is a one-hot vector where only the position of the tag gests "1"
  augmented_y_train = [to_categorical(i, num_classes=n_tags) for i in augmented_y_train]
  new_y_dev = [to_categorical(i, num_classes=n_tags) for i in new_y_dev]
  new_y_test = [to_categorical(i, num_classes=n_tags) for i in new_y_test]

  model = None
  model = create_model(maxlen, n_words)

  train(model, augmented_X_train, augmented_y_train, new_X_dev, new_y_dev)

  test(model, new_X_test, new_y_test)

# %%
number_of_training_models = 10
target_augmented_percentage = 0

print(f"!!!!!! Augmented Percentage {target_augmented_percentage*100}% !!!!!!")

for i in range(number_of_training_models):
  print(f"!!!!!! Starting model number {i+1} !!!!!!")
  create_train_and_validate_model(target_augmented_percentage)
# Out:
# !!!!!! Augmented Percentage 0% !!!!!!
# !!!!!! Starting model number 1 !!!!!!
# Points in X_train after augmentation: 1000
# Points in y_train after augmentation: 1000
# /usr/local/lib/python3.7/dist-packages/keras_contrib/layers/crf.py:346: UserWarning: CRF.loss_function is deprecated and it might be removed in the future. Please use losses.crf_loss instead.
#   warnings.warn('CRF.loss_function is deprecated '
# /usr/local/lib/python3.7/dist-packages/keras_contrib/layers/crf.py:353: UserWarning: CRF.accuracy is deprecated and it might be removed in the future. Please use metrics.crf_accuracy
#   warnings.warn('CRF.accuracy is deprecated and it '
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 651)               0
# _________________________________________________________________
# embedding_3 (Embedding)      (None, 651, 150)          2779950
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 651, 300)          361200
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 651, 5)            1505
# _________________________________________________________________
# crf_3 (CRF)                  (None, 651, 5)            65
# =================================================================
# Total params: 3,142,720
# Trainable params: 3,142,720
# Non-trainable params: 0
# _________________________________________________________________
# Train on 1000 samples, validate on 1000 samples
# Epoch 1/100
# 1000/1000 [==============================] - 48s 48ms/step - loss: 1.4033 - crf_viterbi_accuracy: 0.1145 - accuracy: 0.0331 - val_loss: 0.5734 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 2/100
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.5368 - crf_viterbi_accuracy: 0.9183 - accuracy: 0.0331 - val_loss: 0.4967 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 3/100
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.4938 - crf_viterbi_accuracy: 0.9188 - accuracy: 0.0331 - val_loss: 0.4610 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 4/100
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.4649 - crf_viterbi_accuracy: 0.9188 - accuracy: 0.0331 - val_loss: 0.4353 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 5/100
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.4305 - crf_viterbi_accuracy: 0.9188 - accuracy: 0.0331 - val_loss: 0.4036 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 6/100
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.3836 - crf_viterbi_accuracy: 0.9188 - accuracy: 0.0331 - val_loss: 0.3630 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 7/100
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.3236 - crf_viterbi_accuracy: 0.9215 - accuracy: 0.0331 - val_loss: 0.3176 - val_crf_viterbi_accuracy: 0.9273 - val_accuracy: 0.9273
# Epoch 8/100
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.2659 - crf_viterbi_accuracy: 0.9303 - accuracy: 0.0331 - val_loss: 0.2779 - val_crf_viterbi_accuracy: 0.9284 - val_accuracy: 0.9284
# Epoch 9/100
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.2190 - crf_viterbi_accuracy: 0.9378 - accuracy: 0.0331 - val_loss: 0.2471 - val_crf_viterbi_accuracy: 0.9334 - val_accuracy: 0.9334
# Epoch 10/100
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.1840 - crf_viterbi_accuracy: 0.9430 - accuracy: 0.0331 - val_loss: 0.2306 - val_crf_viterbi_accuracy: 0.9368 - val_accuracy: 0.9368
# Epoch 11/100
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.1625 - crf_viterbi_accuracy: 0.9454 - accuracy: 0.0331 - val_loss: 0.2212 - val_crf_viterbi_accuracy: 0.9398 - val_accuracy: 0.9398
# Epoch 12/100
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.
0
#
# !!!!!! Starting model number 2 !!!!!!
# Points in X_train after augmentation: 1000
# Points in y_train after augmentation: 1000
# /usr/local/lib/python3.7/dist-packages/keras_contrib/layers/crf.py:346: UserWarning: CRF.loss_function is deprecated and it might be removed in the future. Please use losses.crf_loss instead.
#   warnings.warn('CRF.loss_function is deprecated '
# /usr/local/lib/python3.7/dist-packages/keras_contrib/layers/crf.py:353: UserWarning: CRF.accuracy is deprecated and it might be removed in the future. Please use metrics.crf_accuracy
#   warnings.warn('CRF.accuracy is deprecated and it '
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 651)               0
# _________________________________________________________________
# embedding_4 (Embedding)      (None, 651, 150)          2779950
# _________________________________________________________________
# bidirectional_4 (Bidirection (None, 651, 300)          361200
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 651, 5)            1505
# _________________________________________________________________
# crf_4 (CRF)                  (None, 651, 5)            65
# =================================================================
# Total params: 3,142,720
# Trainable params: 3,142,720
# Non-trainable params: 0
# _________________________________________________________________
# Train on 1000 samples, validate on 1000 samples
# Epoch 1/100
# 1000/1000 [==============================] - 45s 45ms/step - loss: 1.2574 - crf_viterbi_accuracy: 0.3372 - accuracy: 0.0331 - val_loss: 0.4502 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 2/100
# 1000/1000 [==============================] - 45s 45ms/step - loss: 0.4664 - crf_viterbi_accuracy: 0.9188 - accuracy: 0.0331 - val_loss: 0.4380 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 3/100
# 1000/1000 [==============================] - 45s 45ms/step - loss: 0.4425 - crf_viterbi_accuracy: 0.9188 - accuracy: 0.0331 - val_loss: 0.4242 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 4/100
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.4292 - crf_viterbi_accuracy: 0.9188 - accuracy: 0.0331 - val_loss: 0.4120 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 5/100
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.4144 - crf_viterbi_accuracy: 0.9188 - accuracy: 0.0331 - val_loss: 0.3974 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 6/100
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.3933 - crf_viterbi_accuracy: 0.9188 - accuracy: 0.0331 - val_loss: 0.3768 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 7/100
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.3599 - crf_viterbi_accuracy: 0.9188 - accuracy: 0.0331 - val_loss: 0.3458 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 8/100
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.3107 - crf_viterbi_accuracy: 0.9188 - accuracy: 0.0331 - val_loss: 0.3040 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 9/100
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.2540 - crf_viterbi_accuracy: 0.9193 - accuracy: 0.0331 - val_loss: 0.2631 - val_crf_viterbi_accuracy: 0.9255 - val_accuracy: 0.9255
# Epoch 10/100
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.2099 - crf_viterbi_accuracy: 0.9248 - accuracy: 0.0331 - val_loss: 0.2408 - val_crf_viterbi_accuracy: 0.9273 - val_accuracy: 0.9273
# Epoch 11/100
# 1000/1000 [==============================] - 45s 45ms/step - loss: 0.1858 - crf_viterbi_accuracy: 0.9326 - accuracy: 0.0331 - val_loss: 0.2281 - val_crf_viterbi_accuracy: 0.9293 - val_accuracy: 0.9293
# Epoch 12/100
# 1000/1000 [==============================] - 45s 45ms/step - loss: 0.1729 - crf_viterbi_accuracy: 0.9356 - accuracy: 0.0331 - val_loss: 0.2218 - val_crf_viterbi_accuracy: 0.9305 - val_accuracy: 0.9305
# Epoch 13/100
# 1000/1000 [==============================] - 45s 45ms/step - loss: 0.1644 - crf_viterbi_accuracy: 0.9370 - accuracy: 0.0331 - val_loss: 0.2205 - val_crf_viterbi_accuracy: 0.9315 - val_accuracy: 0.9315
# Epoch 14/100
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.1590 - crf_viterbi_accuracy: 0.9377 - accuracy: 0.0331 - val_loss: 0.2217 - val_crf_viterbi_accuracy: 0.9323 - val_accuracy: 0.9323
# Epoch 15/100
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.1546 - crf_viterbi_accuracy: 0.9383 - accuracy: 0.0331 - val_loss: 0.2194 - val_crf_viterbi_accuracy: 0.9329 - val_accuracy: 0.9329
# Epoch 16/100
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.1509 - crf_viterbi_accuracy: 0.9391 - accuracy: 0.0331 - val_loss: 0.2239 - val_crf_viterbi_accuracy: 0.9330 - val_accuracy: 0.9330
# Epoch 17/100
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.1482 - crf_viterbi_accuracy: 0.9392 - accuracy: 0.0331 - val_loss: 0.2220 - val_crf_viterbi_accuracy: 0.9330 - val_accuracy: 0.9330
# Epoch 18/100
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.1458 - crf_viterbi_accuracy: 0.9397 - accuracy: 0.0331 - val_loss: 0.2238 - val_crf_viterbi_accuracy: 0.9330 - val_accuracy: 0.9330
# Epoch 19/100
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.1433 - crf_viterbi_accuracy: 0.9400 - accuracy: 0.0331 - val_loss: 0.2300 - val_crf_viterbi_accuracy: 0.9327 - val_accuracy: 0.9327
# Epoch 20/100
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.1414 - crf_viterbi_accuracy: 0.9397 - accuracy: 0.0331 - val_loss: 0.2315 - val_crf_viterbi_accuracy: 0.9328 - val_accuracy: 0.9328
# Epoch 21/100
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.1397 - crf_viterbi_accuracy: 0.9403 - accuracy: 0.0331 - val_loss: 0.2292 - val_crf_viterbi_accuracy: 0.9328 - val_accuracy: 0.9328
# Epoch 22/100
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.1376 - crf_viterbi_accuracy: 0.9403 - accuracy: 0.0331 - val_loss: 0.2323 - val_crf_viterbi_accuracy: 0.9326 - val_accuracy: 0.9326
# Epoch 23/100
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.1360 - crf_viterbi_accuracy: 0.9402 - accuracy: 0.0331 - val_loss: 0.2353 - val_crf_viterbi_accuracy: 0.9326 - val_accuracy: 0.9326
# Epoch 24/100
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.1346 - crf_viterbi_accuracy: 0.9406 - accuracy: 0.0331 - val_loss: 0.2354 - val_crf_viterbi_accuracy: 0.9330 - val_accuracy: 0.9330
# Epoch 25/100
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.1328 - crf_viterbi_accuracy: 0.9405 - accuracy: 0.0331 - val_loss: 0.2387 - val_crf_viterbi_accuracy: 0.9329 - val_accuracy: 0.9329
# 1000/1000 [==============================] - 18s 18ms/step
# F1-score: 20.2%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-337f9b400e1f> in <module>()
#       6 for i in range(number_of_training_models):
#       7   print(f"!!!!!! Starting model number {i+1} !!!!!!")
# ----> 8   create_train_and_validate_model(target_augmented_percentage)
#
# <ipython-input-32-b60e157c9e1c> in create_train_and_validate_model(augmented_percentage)
#      37   train(model, augmented_X_train, augmented_y_train, new_X_dev, new_y_dev)
#      38
# ---> 39   test(model, new_X_test, new_y_test)
#
# <ipython-input-31-87abc3696d8b> in test(model, X_test_df, y_test_df)
#       7
#       8   print("F1-score: {:.1%}".format(f1_score(test_labels, pred_labels)))
# ----> 9   report = classification_report(y_pred=pred_labels, y_true=test_labels, output_dict=True)
#      10   df = pd.DataFrame(report).transpose()
#      11   print("Classification Report:")
#
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py in classification_report(y_true, y_pred, digits, suffix, output_dict, mode, sample_weight, zero_division, scheme)
#     709             sample_weight=sample_weight,
#     710             zero_division=zero_division,
# --> 711             suffix=suffix
#     712         )
#     713         reporter.write('{} avg'.format(average), avg_p, avg_r, avg_f1, support)
#
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py in precision_recall_fscore_support(y_true, y_pred, average, warn_for, beta, sample_weight, zero_division, suffix)
#     137         scheme=None,
#     138         suffix=suffix,
# --> 139         extract_tp_actual_correct=extract_tp_actual_correct
#     140     )
#     141
#
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/v1.py in _precision_recall_fscore_support(y_true, y_pred, average, warn_for, beta, sample_weight, zero_division, scheme, suffix, extract_tp_actual_correct)
#     122     check_consistent_length(y_true, y_pred)
#     123
# --> 124     pred_sum, tp_sum, true_sum = extract_tp_actual_correct(y_true, y_pred, suffix, scheme)
#     125
#     126     if average == 'micro':
#
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py in extract_tp_actual_correct(y_true, y_pred, suffix, *args)
#     111         for type_name, start, end in get_entities(y_true, suffix):
#     112             entities_true[type_name].add((start, end))
# --> 113         for type_name, start, end in get_entities(y_pred, suffix):
#     114             entities_pred[type_name].add((start, end))
#     115
#
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py in get_entities(seq, suffix)
#     180     chunks = []
#     181     for i, chunk in enumerate(seq + ['O']):
# --> 182         _validate_chunk(chunk, suffix)
#     183
#     184         if suffix:
#
# KeyboardInterrupt:

# %%
number_of_training_models = 10
target_augmented_percentage = 0.25

print(f"!!!!!! Augmented Percentage {target_augmented_percentage*100}% !!!!!!")

for i in range(number_of_training_models):
  print(f"!!!!!! Starting model number {i+1} !!!!!!")
  create_train_and_validate_model(target_augmented_percentage)
# Out:
# !!!!!! Augmented Percentage 25.0% !!!!!!
# !!!!!! Starting model number 1 !!!!!!
# Points in X_train after augmentation: 625
# Points in y_train after augmentation: 625
# /usr/local/lib/python3.7/dist-packages/keras_contrib/layers/crf.py:346: UserWarning: CRF.loss_function is deprecated and it might be removed in the future. Please use losses.crf_loss instead.
#   warnings.warn('CRF.loss_function is deprecated '
# /usr/local/lib/python3.7/dist-packages/keras_contrib/layers/crf.py:353: UserWarning: CRF.accuracy is deprecated and it might be removed in the future. Please use metrics.crf_accuracy
#   warnings.warn('CRF.accuracy is deprecated and it '
# Model: "model_31"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_31 (InputLayer)        (None, 651)               0
# _________________________________________________________________
# embedding_31 (Embedding)     (None, 651, 150)          2779950
# _________________________________________________________________
# bidirectional_31 (Bidirectio (None, 651, 300)          362400
# _________________________________________________________________
# cu_dnnlstm_62 (CuDNNLSTM)    (None, 651, 300)          722400
# _________________________________________________________________
# time_distributed_31 (TimeDis (None, 651, 5)            1505
# _________________________________________________________________
# crf_31 (CRF)                 (None, 651, 5)            65
# =================================================================
# Total params: 3,866,320
# Trainable params: 3,866,320
# Non-trainable params: 0
# _________________________________________________________________
# (1000, 651)
# 1000
# Train on 625 samples, validate on 1000 samples
# Epoch 1/100
# 625/625 [==============================] - 14s 22ms/step - loss: 1.7704 - crf_viterbi_accuracy: 0.3098 - accuracy: 0.0144 - val_loss: 0.6219 - val_crf_viterbi_accuracy: 0.9221 - val_accuracy: 0.9221
# Epoch 2/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.6054 - crf_viterbi_accuracy: 0.9234 - accuracy: 0.0144 - val_loss: 0.5878 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 3/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.5709 - crf_viterbi_accuracy: 0.9247 - accuracy: 0.0144 - val_loss: 0.5629 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 4/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.5534 - crf_viterbi_accuracy: 0.9256 - accuracy: 0.0144 - val_loss: 0.5447 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 5/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.5382 - crf_viterbi_accuracy: 0.9252 - accuracy: 0.0144 - val_loss: 0.5295 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 6/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.5243 - crf_viterbi_accuracy: 0.9252 - accuracy: 0.0144 - val_loss: 0.5163 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 7/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.5088 - crf_viterbi_accuracy: 0.9251 - accuracy: 0.0144 - val_loss: 0.5018 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 8/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.4919 - crf_viterbi_accuracy: 0.9253 - accuracy: 0.0144 - val_loss: 0.4921 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 9/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.4795 - crf_viterbi_accuracy: 0.9251 - accuracy: 0.0144 - val_loss: 0.4764 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 10/100
# 625/625 [==============================] - 10s 15ms/step - loss: 0.4579 - crf_viterbi_accuracy: 0.9244 - accuracy: 0.0144 - val_loss: 0.4558 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 11/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.4237 - crf_viterbi_accuracy: 0.9247 - accuracy: 0.0144 - val_loss: 0.4353 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 12/100
# 625/625 [==============================] - 10s 15ms/step - loss: 0.3812 - crf_viterbi_accuracy: 0.9246 - accuracy: 0.0144 - val_loss: 0.3986 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 13/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3230 - crf_viterbi_accuracy: 0.9250 - accuracy: 0.0144 - val_loss: 0.3492 - val_crf_viterbi_accuracy: 0.9259 - val_accuracy: 0.9259
# Epoch 14/100
# 625/625 [==============================] - 10s 15ms/step - loss: 0.2494 - crf_viterbi_accuracy: 0.9319 - accuracy: 0.0144 - val_loss: 0.3056 - val_crf_viterbi_accuracy: 0.9310 - val_accuracy: 0.9310
# Epoch 15/100
# 625/625 [==============================] - 10s 15ms/step - loss: 0.1817 - crf_viterbi_accuracy: 0.9437 - accuracy: 0.0144 - val_loss: 0.2901 - val_crf_viterbi_accuracy: 0.9336 - val_accuracy: 0.9336
# Epoch 16/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.1507 - crf_viterbi_accuracy: 0.9478 - accuracy: 0.0144 - val_loss: 0.3019 - val_crf_viterbi_accuracy: 0.9339 - val_accuracy: 0.9339
# Epoch 17/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.1410 - crf_viterbi_accuracy: 0.9494 - accuracy: 0.0144 - val_loss: 0.3392 - val_crf_viterbi_accuracy: 0.9352 - val_accuracy: 0.9352
# Epoch 18/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.1358 - crf_viterbi_accuracy: 0.9497 - accuracy: 0.0144 - val_loss: 0.3150 - val_crf_viterbi_accuracy: 0.9344 - val_accuracy: 0.9344
# Epoch 19/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.1313 - crf_viterbi_accuracy: 0.9494 - accuracy: 0.0144 - val_loss: 0.3491 - val_crf_viterbi_accuracy: 0.9353 - val_accuracy: 0.9353
# Epoch 20/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.1290 - crf_viterbi_accuracy: 0.9497 - accuracy: 0.0144 - val_loss: 0.3479 - val_crf_viterbi_accuracy: 0.9356 - val_accuracy: 0.9356
# 1000/1000 [==============================] - 12s 12ms/step
# F1-score: 21.3%
# Classification Report:
# ,precision,recall,f1-score,support
# Chemical,0.004739336492890996,9.853187506158242e-05,0.00019305019305019308,20298.0
# Disease,0.3082302042459,0.35895483039428205,0.33166427585460256,17069.0
# micro avg,0.30192118226600984,0.16402173040383225,0.21256524528759949,37367.0
# macro avg,0.15648477036939548,0.17952668113467182,0.1659286630238264,37367.0
# weighted avg,0.14337197014493988,0.16402173040383225,0.15160692743278145,37367.0
#
# !!!!!! Starting model number 2 !!!!!!
# Points in X_train after augmentation: 625
# Points in y_train after augmentation: 625
# /usr/local/lib/python3.7/dist-packages/keras_contrib/layers/crf.py:346: UserWarning: CRF.loss_function is deprecated and it might be removed in the future. Please use losses.crf_loss instead.
#   warnings.warn('CRF.loss_function is deprecated '
# /usr/local/lib/python3.7/dist-packages/keras_contrib/layers/crf.py:353: UserWarning: CRF.accuracy is deprecated and it might be removed in the future. Please use metrics.crf_accuracy
#   warnings.warn('CRF.accuracy is deprecated and it '
# Model: "model_32"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_32 (InputLayer)        (None, 651)               0
# _________________________________________________________________
# embedding_32 (Embedding)     (None, 651, 150)          2779950
# _________________________________________________________________
# bidirectional_32 (Bidirectio (None, 651, 300)          362400
# _________________________________________________________________
# cu_dnnlstm_64 (CuDNNLSTM)    (None, 651, 300)          722400
# _________________________________________________________________
# time_distributed_32 (TimeDis (None, 651, 5)            1505
# _________________________________________________________________
# crf_32 (CRF)                 (None, 651, 5)            65
# =================================================================
# Total params: 3,866,320
# Trainable params: 3,866,320
# Non-trainable params: 0
# _________________________________________________________________
# (1000, 651)
# 1000
# Train on 625 samples, validate on 1000 samples
# Epoch 1/100
# 625/625 [==============================] - 14s 22ms/step - loss: 1.0087 - crf_viterbi_accuracy: 0.6260 - accuracy: 0.0144 - val_loss: 0.5752 - val_crf_viterbi_accuracy: 0.9247 - val_accuracy: 0.9247
# Epoch 2/100
# 625/625 [==============================] - 10s 15ms/step - loss: 0.5398 - crf_viterbi_accuracy: 0.9243 - accuracy: 0.0144 - val_loss: 0.5192 - val_crf_viterbi_accuracy: 0.9247 - val_accuracy: 0.9247
# Epoch 3/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.5037 - crf_viterbi_accuracy: 0.9254 - accuracy: 0.0144 - val_loss: 0.4950 - val_crf_viterbi_accuracy: 0.9249 - val_accuracy: 0.9249
# Epoch 4/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.4747 - crf_viterbi_accuracy: 0.9244 - accuracy: 0.0144 - val_loss: 0.4759 - val_crf_viterbi_accuracy: 0.9248 - val_accuracy: 0.9248
# Epoch 5/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.4453 - crf_viterbi_accuracy: 0.9248 - accuracy: 0.0144 - val_loss: 0.4514 - val_crf_viterbi_accuracy: 0.9249 - val_accuracy: 0.9249
# Epoch 6/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.4083 - crf_viterbi_accuracy: 0.9243 - accuracy: 0.0144 - val_loss: 0.4174 - val_crf_viterbi_accuracy: 0.9252 - val_accuracy: 0.9252
# Epoch 7/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3578 - crf_viterbi_accuracy: 0.9221 - accuracy: 0.0144 - val_loss: 0.3919 - val_crf_viterbi_accuracy: 0.9252 - val_accuracy: 0.9252
# Epoch 8/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3125 - crf_viterbi_accuracy: 0.9224 - accuracy: 0.0144 - val_loss: 0.3699 - val_crf_viterbi_accuracy: 0.9250 - val_accuracy: 0.9250
# Epoch 9/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.2735 - crf_viterbi_accuracy: 0.9210 - accuracy: 0.0144 - val_loss: 0.3353 - val_crf_viterbi_accuracy: 0.9238 - val_accuracy: 0.9238
# Epoch 10/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.2354 - crf_viterbi_accuracy: 0.9230 - accuracy: 0.0144 - val_loss: 0.3171 - val_crf_viterbi_accuracy: 0.9252 - val_accuracy: 0.9252
# Epoch 11/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.1974 - crf_viterbi_accuracy: 0.9285 - accuracy: 0.0144 - val_loss: 0.2924 - val_crf_viterbi_accuracy: 0.9272 - val_accuracy: 0.9272
# Epoch 12/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.1679 - crf_viterbi_accuracy: 0.9366 - accuracy: 0.0144 - val_loss: 0.2779 - val_crf_viterbi_accuracy: 0.9320 - val_accuracy: 0.9320
# Epoch 13/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.1389 - crf_viterbi_accuracy: 0.9458 - accuracy: 0.0144 - val_loss: 0.3123 - val_crf_viterbi_accuracy: 0.9339 - val_accuracy: 0.9339
# Epoch 14/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.1184 - crf_viterbi_accuracy: 0.9525 - accuracy: 0.0144 - val_loss: 0.2988 - val_crf_viterbi_accuracy: 0.9358 - val_accuracy: 0.9358
# Epoch 15/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.1063 - crf_viterbi_accuracy: 0.9536 - accuracy: 0.0144 - val_loss: 0.3085 - val_crf_viterbi_accuracy: 0.9344 - val_accuracy: 0.9344
# Epoch 16/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.0968 - crf_viterbi_accuracy: 0.9539 - accuracy: 0.0144 - val_loss: 0.3214 - val_crf_viterbi_accuracy: 0.9330 - val_accuracy: 0.9330
# Epoch 17/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.0899 - crf_viterbi_accuracy: 0.9605 - accuracy: 0.0144 - val_loss: 0.3250 - val_crf_viterbi_accuracy: 0.9342 - val_accuracy: 0.9342
# 1000/1000 [==============================] - 12s 12ms/step
# F1-score: 18.7%
# Classification Report:
# ,precision,recall,f1-score,support
# Chemical,0.28340270856539834,0.23815154202384473,0.2588140811136394,20298.0
# Disease,0.26703372333103925,0.022731267209561194,0.04189612352877659,17069.0
# micro avg,0.282117774176121,0.1397489763695239,0.1869105356407824,37367.0
# macro avg,0.2752182159482188,0.13044140461670295,0.150355102321208,37367.0
# weighted avg,0.2759254636978608,0.1397489763695239,0.1597273838134541,37367.0
#
# !!!!!! Starting model number 3 !!!!!!
# Points in X_train after augmentation: 625
# Points in y_train after augmentation: 625
# /usr/local/lib/python3.7/dist-packages/keras_contrib/layers/crf.py:346: UserWarning: CRF.loss_function is deprecated and it might be removed in the future. Please use losses.crf_loss instead.
#   warnings.warn('CRF.loss_function is deprecated '
# /usr/local/lib/python3.7/dist-packages/keras_contrib/layers/crf.py:353: UserWarning: CRF.accuracy is deprecated and it might be removed in the future. Please use metrics.crf_accuracy
#   warnings.warn('CRF.accuracy is deprecated and it '
# Model: "model_33"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_33 (InputLayer)        (None, 651)               0
# _________________________________________________________________
# embedding_33 (Embedding)     (None, 651, 150)          2779950
# _________________________________________________________________
# bidirectional_33 (Bidirectio (None, 651, 300)          362400
# _________________________________________________________________
# cu_dnnlstm_66 (CuDNNLSTM)    (None, 651, 300)          722400
# _________________________________________________________________
# time_distributed_33 (TimeDis (None, 651, 5)            1505
# _________________________________________________________________
# crf_33 (CRF)                 (None, 651, 5)            65
# =================================================================
# Total params: 3,866,320
# Trainable params: 3,866,320
# Non-trainable params: 0
# _________________________________________________________________
# (1000, 651)
# 1000
# Train on 625 samples, validate on 1000 samples
# Epoch 1/100
# 625/625 [==============================] - 14s 22ms/step - loss: 1.4179 - crf_viterbi_accuracy: 0.3427 - accuracy: 0.0143 - val_loss: 0.4844 - val_crf_viterbi_accuracy: 0.9210 - val_accuracy: 0.9210
# Epoch 2/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.4380 - crf_viterbi_accuracy: 0.9247 - accuracy: 0.0143 - val_loss: 0.4280 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 3/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.4303 - crf_viterbi_accuracy: 0.9258 - accuracy: 0.0143 - val_loss: 0.4148 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 4/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.4117 - crf_viterbi_accuracy: 0.9253 - accuracy: 0.0143 - val_loss: 0.4012 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 5/100
# 625/625 [==============================] - 10s 15ms/step - loss: 0.4031 - crf_viterbi_accuracy: 0.9250 - accuracy: 0.0143 - val_loss: 0.3950 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 6/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3953 - crf_viterbi_accuracy: 0.9245 - accuracy: 0.0143 - val_loss: 0.3884 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 7/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3893 - crf_viterbi_accuracy: 0.9247 - accuracy: 0.0143 - val_loss: 0.3825 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 8/100
# 625/625 [==============================] - 10s 15ms/step - loss: 0.3826 - crf_viterbi_accuracy: 0.9249 - accuracy: 0.0143 - val_loss: 0.3767 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 9/100
# 625/625 [==============================] - 10s 15ms/step - loss: 0.3757 - crf_viterbi_accuracy: 0.9251 - accuracy: 0.0143 - val_loss: 0.3696 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 10/100
# 625/625 [==============================] - 10s 15ms/step - loss: 0.3667 - crf_viterbi_accuracy: 0.9249 - accuracy: 0.0143 - val_loss: 0.3669 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 11/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3583 - crf_viterbi_accuracy: 0.9252 - accuracy: 0.0143 - val_loss: 0.3537 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 12/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3379 - crf_viterbi_accuracy: 0.9251 - accuracy: 0.0143 - val_loss: 0.3393 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 13/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3077 - crf_viterbi_accuracy: 0.9256 - accuracy: 0.0143 - val_loss: 0.3126 - val_crf_viterbi_accuracy: 0.9264 - val_accuracy: 0.9264
# Epoch 14/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.2667 - crf_viterbi_accuracy: 0.9351 - accuracy: 0.0143 - val_loss: 0.2852 - val_crf_viterbi_accuracy: 0.9327 - val_accuracy: 0.9327
# Epoch 15/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.2217 - crf_viterbi_accuracy: 0.9438 - accuracy: 0.0143 - val_loss: 0.2622 - val_crf_viterbi_accuracy: 0.9344 - val_accuracy: 0.9344
# Epoch 16/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.1762 - crf_viterbi_accuracy: 0.9451 - accuracy: 0.0143 - val_loss: 0.2385 - val_crf_viterbi_accuracy: 0.9352 - val_accuracy: 0.9352
# Epoch 17/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.1346 - crf_viterbi_accuracy: 0.9536 - accuracy: 0.0143 - val_loss: 0.2232 - val_crf_viterbi_accuracy: 0.9412 - val_accuracy: 0.9412
# Epoch 18/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.1030 - crf_viterbi_accuracy: 0.9736 - accuracy: 0.0143 - val_loss: 0.2222 - val_crf_viterbi_accuracy: 0.9476 - val_accuracy: 0.9476
# Epoch 19/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.0825 - crf_viterbi_accuracy: 0.9833 - accuracy: 0.0143 - val_loss: 0.2237 - val_crf_viterbi_accuracy: 0.9513 - val_accuracy: 0.9513
# Epoch 20/100
# 625/625 [==============================] - 10s 15ms/step - loss: 0.0703 - crf_viterbi_accuracy: 0.9859 - accuracy: 0.0143 - val_loss: 0.2289 - val_crf_viterbi_accuracy: 0.9521 - val_accuracy: 0.9521
# Epoch 21/100
# 625/625 [==============================] - 10s 15ms/step - loss: 0.0613 - crf_viterbi_accuracy: 0.9876 - accuracy: 0.0143 - val_loss: 0.2413 - val_crf_viterbi_accuracy: 0.9530 - val_accuracy: 0.9530
# Epoch 22/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.0545 - crf_viterbi_accuracy: 0.9889 - accuracy: 0.0143 - val_loss: 0.2364 - val_crf_viterbi_accuracy: 0.9521 - val_accuracy: 0.9521
# Epoch 23/100
# 625/625 [==============================] - 10s 15ms/step - loss: 0.0489 - crf_viterbi_accuracy: 0.9899 - accuracy: 0.0143 - val_loss: 0.2519 - val_crf_viterbi_accuracy: 0.9536 - val_accuracy: 0.9536
# 1000/1000 [==============================] - 12s 12ms/step
# F1-score: 43.2%
# Classification Report:
# ,precision,recall,f1-score,support
# Chemical,0.5584867075664621,0.2690905507931816,0.36318904182458944,20298.0
# Disease,0.6259236720855429,0.4218173296619603,0.5039899202015959,17069.0
# micro avg,0.5949349245876991,0.3388551395616453,0.4317817561807332,37367.0
# macro avg,0.5922051898260026,0.3454539402275709,0.4335894810130927,37367.0
# weighted avg,0.5892914697195969,0.3388551395616453,0.42750595763311366,37367.0
#
# !!!!!! Starting model number 4 !!!!!!
# Points in X_train after augmentation: 625
# Points in y_train after augmentation: 625
# /usr/local/lib/python3.7/dist-packages/keras_contrib/layers/crf.py:346: UserWarning: CRF.loss_function is deprecated and it might be removed in the future. Please use losses.crf_loss instead.
#   warnings.warn('CRF.loss_function is deprecated '
# /usr/local/lib/python3.7/dist-packages/keras_contrib/layers/crf.py:353: UserWarning: CRF.accuracy is deprecated and it might be removed in the future. Please use metrics.crf_accuracy
#   warnings.warn('CRF.accuracy is deprecated and it '
# Model: "model_34"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_34 (InputLayer)        (None, 651)               0
# _________________________________________________________________
# embedding_34 (Embedding)     (None, 651, 150)          2779950
# _________________________________________________________________
# bidirectional_34 (Bidirectio (None, 651, 300)          362400
# _________________________________________________________________
# cu_dnnlstm_68 (CuDNNLSTM)    (None, 651, 300)          722400
# _________________________________________________________________
# time_distributed_34 (TimeDis (None, 651, 5)            1505
# _________________________________________________________________
# crf_34 (CRF)                 (None, 651, 5)            65
# =================================================================
# Total params: 3,866,320
# Trainable params: 3,866,320
# Non-trainable params: 0
# _________________________________________________________________
# (1000, 651)
# 1000
# Train on 625 samples, validate on 1000 samples
# Epoch 1/100
# 625/625 [==============================] - 14s 23ms/step - loss: 1.2973 - crf_viterbi_accuracy: 0.6289 - accuracy: 0.0143 - val_loss: 0.6701 - val_crf_viterbi_accuracy: 0.9242 - val_accuracy: 0.9242
# Epoch 2/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.5811 - crf_viterbi_accuracy: 0.9245 - accuracy: 0.0143 - val_loss: 0.5337 - val_crf_viterbi_accuracy: 0.9245 - val_accuracy: 0.9245
# Epoch 3/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.4979 - crf_viterbi_accuracy: 0.9235 - accuracy: 0.0143 - val_loss: 0.4829 - val_crf_viterbi_accuracy: 0.9255 - val_accuracy: 0.9255
# Epoch 4/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.4695 - crf_viterbi_accuracy: 0.9254 - accuracy: 0.0143 - val_loss: 0.4677 - val_crf_viterbi_accuracy: 0.9255 - val_accuracy: 0.9255
# Epoch 5/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.4564 - crf_viterbi_accuracy: 0.9254 - accuracy: 0.0143 - val_loss: 0.4516 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 6/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.4413 - crf_viterbi_accuracy: 0.9255 - accuracy: 0.0143 - val_loss: 0.4371 - val_crf_viterbi_accuracy: 0.9252 - val_accuracy: 0.9252
# Epoch 7/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.4246 - crf_viterbi_accuracy: 0.9250 - accuracy: 0.0143 - val_loss: 0.4212 - val_crf_viterbi_accuracy: 0.9255 - val_accuracy: 0.9255
# Epoch 8/100
# 625/625 [==============================] - 10s 15ms/step - loss: 0.4046 - crf_viterbi_accuracy: 0.9249 - accuracy: 0.0143 - val_loss: 0.4035 - val_crf_viterbi_accuracy: 0.9255 - val_accuracy: 0.9255
# Epoch 9/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3776 - crf_viterbi_accuracy: 0.9248 - accuracy: 0.0143 - val_loss: 0.3815 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 10/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3430 - crf_viterbi_accuracy: 0.9246 - accuracy: 0.0143 - val_loss: 0.3528 - val_crf_viterbi_accuracy: 0.9255 - val_accuracy: 0.9255
# Epoch 11/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.2981 - crf_viterbi_accuracy: 0.9251 - accuracy: 0.0143 - val_loss: 0.3155 - val_crf_viterbi_accuracy: 0.9255 - val_accuracy: 0.9255
# Epoch 12/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.2458 - crf_viterbi_accuracy: 0.9250 - accuracy: 0.0143 - val_loss: 0.2886 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 13/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.1935 - crf_viterbi_accuracy: 0.9270 - accuracy: 0.0143 - val_loss: 0.2657 - val_crf_viterbi_accuracy: 0.9292 - val_accuracy: 0.9292
# Epoch 14/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.1527 - crf_viterbi_accuracy: 0.9384 - accuracy: 0.0143 - val_loss: 0.2532 - val_crf_viterbi_accuracy: 0.9319 - val_accuracy: 0.9319
# Epoch 15/100
# 625/625 [==============================] - 10s 15ms/step - loss: 0.1372 - crf_viterbi_accuracy: 0.9424 - accuracy: 0.0143 - val_loss: 0.2792 - val_crf_viterbi_accuracy: 0.9339 - val_accuracy: 0.9339
# Epoch 16/100
# 625/625 [==============================] - 10s 15ms/step - loss: 0.1288 - crf_viterbi_accuracy: 0.9507 - accuracy: 0.0143 - val_loss: 0.3079 - val_crf_viterbi_accuracy: 0.9353 - val_accuracy: 0.9353
# Epoch 17/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.1221 - crf_viterbi_accuracy: 0.9569 - accuracy: 0.0143 - val_loss: 0.2953 - val_crf_viterbi_accuracy: 0.9381 - val_accuracy: 0.9381
# Epoch 18/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.1117 - crf_viterbi_accuracy: 0.9609 - accuracy: 0.0143 - val_loss: 0.2924 - val_crf_viterbi_accuracy: 0.9412 - val_accuracy: 0.9412
# Epoch 19/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.1029 - crf_viterbi_accuracy: 0.9701 - accuracy: 0.0143 - val_loss: 0.2988 - val_crf_viterbi_accuracy: 0.9435 - val_accuracy: 0.9435
# 1000/1000 [==============================] - 13s 13ms/step
# F1-score: 20.8%
# Classification Report:
# ,precision,recall,f1-score,support
# Chemical,0.08950827101744845,0.019460045324662528,0.031969568208490146,20298.0
# Disease,0.282464884458541,0.3652235045989806,0.3185569380924398,17069.0
# micro avg,0.25031152059811956,0.1774025209409372,0.20764291307752544,37367.0
# macro avg,0.18598657773799473,0.1923417749618216,0.17526325315046498,37367.0
# weighted avg,0.17764958380215176,0.1774025209409372,0.16288079513463183,37367.0
#
# !!!!!! Starting model number 5 !!!!!!
# Points in X_train after augmentation: 625
# Points in y_train after augmentation: 625
# /usr/local/lib/python3.7/dist-packages/keras_contrib/layers/crf.py:346: UserWarning: CRF.loss_function is deprecated and it might be removed in the future. Please use losses.crf_loss instead.
#   warnings.warn('CRF.loss_function is deprecated '
# /usr/local/lib/python3.7/dist-packages/keras_contrib/layers/crf.py:353: UserWarning: CRF.accuracy is deprecated and it might be removed in the future. Please use metrics.crf_accuracy
#   warnings.warn('CRF.accuracy is deprecated and it '
# Model: "model_35"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_35 (InputLayer)        (None, 651)               0
# _________________________________________________________________
# embedding_35 (Embedding)     (None, 651, 150)          2779950
# _________________________________________________________________
# bidirectional_35 (Bidirectio (None, 651, 300)          362400
# _________________________________________________________________
# cu_dnnlstm_70 (CuDNNLSTM)    (None, 651, 300)          722400
# _________________________________________________________________
# time_distributed_35 (TimeDis (None, 651, 5)            1505
# _________________________________________________________________
# crf_35 (CRF)                 (None, 651, 5)            65
# =================================================================
# Total params: 3,866,320
# Trainable params: 3,866,320
# Non-trainable params: 0
# _________________________________________________________________
# (1000, 651)
# 1000
# Train on 625 samples, validate on 1000 samples
# Epoch 1/100
# 625/625 [==============================] - 14s 23ms/step - loss: 1.1547 - crf_viterbi_accuracy: 0.7953 - accuracy: 0.0144 - val_loss: 1.1402 - val_crf_viterbi_accuracy: 0.9241 - val_accuracy: 0.9241
# Epoch 2/100
# 625/625 [==============================] - 10s 16ms/step - loss: 1.1315 - crf_viterbi_accuracy: 0.9238 - accuracy: 0.0144 - val_loss: 1.1201 - val_crf_viterbi_accuracy: 0.9241 - val_accuracy: 0.9241
- val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 26/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.7217 - crf_viterbi_accuracy: 0.9250 - accuracy: 0.0144 - val_loss: 0.7141 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 27/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.7084 - crf_viterbi_accuracy: 0.9248 - accuracy: 0.0144 - val_loss: 0.7010 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 28/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.6954 - crf_viterbi_accuracy: 0.9257 - accuracy: 0.0144 - val_loss: 0.6882 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 29/100
# 625/625 [==============================] - 10s 15ms/step - loss: 0.6828 - crf_viterbi_accuracy: 0.9252 - accuracy: 0.0144 - val_loss: 0.6757 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 30/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.6704 - crf_viterbi_accuracy: 0.9254 - accuracy: 0.0144 - val_loss: 0.6636 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 31/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.6585 - crf_viterbi_accuracy: 0.9253 - accuracy: 0.0144 - val_loss: 0.6518 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 32/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.6468 - crf_viterbi_accuracy: 0.9252 - accuracy: 0.0144 - val_loss: 0.6403 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 33/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.6355 - crf_viterbi_accuracy: 0.9255 - accuracy: 0.0144 - val_loss: 0.6292 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 34/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.6245 - crf_viterbi_accuracy: 0.9257 - accuracy: 0.0144 - val_loss: 0.6184 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 35/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.6138 - crf_viterbi_accuracy: 0.9252 - accuracy: 0.0144 - val_loss: 0.6079 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 36/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.6035 - crf_viterbi_accuracy: 0.9246 - accuracy: 0.0144 - val_loss: 0.5978 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 37/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.5935 - crf_viterbi_accuracy: 0.9259 - accuracy: 0.0144 - val_loss: 0.5880 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 38/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.5838 - crf_viterbi_accuracy: 0.9251 - accuracy: 0.0144 - val_loss: 0.5785 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 39/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.5744 - crf_viterbi_accuracy: 0.9248 - accuracy: 0.0144 - val_loss: 0.5693 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 40/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.5654 - crf_viterbi_accuracy: 0.9256 - accuracy: 0.0144 - val_loss: 0.5604 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 41/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.5566 - crf_viterbi_accuracy: 0.9255 - accuracy: 0.0144 - val_loss: 0.5519 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 42/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.5482 - crf_viterbi_accuracy: 0.9251 - accuracy: 0.0144 - val_loss: 0.5437 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 43/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.5401 - crf_viterbi_accuracy: 0.9254 - accuracy: 0.0144 - val_loss: 0.5357 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 44/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.5323 - crf_viterbi_accuracy: 0.9249 - accuracy: 0.0144 - val_loss: 0.5280 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 45/100
# 625/625 [==============================] - 10s 16ms/step - loss: 0.5247 - crf_viterbi_accuracy: 0.9255 - accuracy: 0.0144 - val_loss: 0.5207 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 46/100
# 600/625 [===========================>..] - ETA: 0s - loss: 0.5174 - crf_viterbi_accuracy: 0.9253 - accuracy: 0.0142
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-70-6d7dae9da1f9> in <module>()
#       6 for i in range(number_of_training_models):
#       7   print(f"!!!!!! Starting model number {i+1} !!!!!!")
# ----> 8   create_train_and_validate_model(target_augmented_percentage)
#
# <ipython-input-66-0473c2e50c5c> in create_train_and_validate_model(augmented_percentage)
#      53   # print(new_y_test.shape)
#      54
# ---> 55   train(model, augmented_X_train, augmented_y_train, new_X_dev, new_y_dev)
#      56
#      57   test(model, new_X_test, new_y_test)
#
# <ipython-input-68-0c3377399749> in train(model, X_train_df, y_train_df, X_dev_df, y_dev_df)
#       5   callbacks_list = [early_stopping]
#       6
# ----> 7   history = model.fit(X_train_df, np.array(y_train_df), batch_size=100, epochs=100, validation_data=(X_dev_df,  np.array(y_dev_df)), verbose=1, callbacks=callbacks_list)
#       8   plot_history(history)
#
# /tensorflow-1.15.2/python3.7/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# /tensorflow-1.15.2/python3.7/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     208                                          batch_size=batch_size,
#     209                                          callbacks=callbacks,
# --> 210                                          verbose=0)
#     211                     val_outs = to_list(val_outs)
#     212                     # Same labels assumed.
#
# /tensorflow-1.15.2/python3.7/keras/engine/training_arrays.py in test_loop(model, f, ins, batch_size, verbose, steps, callbacks)
#     447             batch_logs = {'batch': batch_index, 'size': len(batch_ids)}
#     448             callbacks._call_batch_hook('test', 'begin', batch_index, batch_logs)
# --> 449             batch_outs = f(ins_batch)
#     450             if isinstance(batch_outs, list):
#     451                 if batch_index == 0:
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3474
#    3475     fetched = self._callable_fn(*array_vals,
# -> 3476                                 run_metadata=self.run_metadata)
#    3477     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3478     output_structure = nest.pack_sequence_as(
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
number_of_training_models = 10
target_augmented_percentage = 0.5

print(f"!!!!!! Augmented Percentage {target_augmented_percentage*100}% !!!!!!")

for i in range(number_of_training_models):
  print(f"!!!!!! Starting model number {i+1} !!!!!!")
  create_train_and_validate_model(target_augmented_percentage)

# %%
number_of_training_models = 10
target_augmented_percentage = 0.75

print(f"!!!!!! Augmented Percentage {target_augmented_percentage*100}% !!!!!!")

for i in range(number_of_training_models):
  print(f"!!!!!! Starting model number {i+1} !!!!!!")
  create_train_and_validate_model(target_augmented_percentage)

# %%
number_of_training_models = 10
target_augmented_percentage = 1

print(f"!!!!!! Augmented Percentage {target_augmented_percentage*100}% !!!!!!")

for i in range(number_of_training_models):
  print(f"!!!!!! Starting model number {i+1} !!!!!!")
  create_train_and_validate_model(target_augmented_percentage)
# Out:
# !!!!!! Augmented Percentage 100% !!!!!!
# !!!!!! Starting model number 1 !!!!!!
# Points in X_train after augmentation: 2000
# Points in y_train after augmentation: 2000
# /usr/local/lib/python3.7/dist-packages/keras_contrib/layers/crf.py:346: UserWarning: CRF.loss_function is deprecated and it might be removed in the future. Please use losses.crf_loss instead.
#   warnings.warn('CRF.loss_function is deprecated '
# /usr/local/lib/python3.7/dist-packages/keras_contrib/layers/crf.py:353: UserWarning: CRF.accuracy is deprecated and it might be removed in the future. Please use metrics.crf_accuracy
#   warnings.warn('CRF.accuracy is deprecated and it '
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 651)               0
# _________________________________________________________________
# embedding_5 (Embedding)      (None, 651, 150)          2779950
# _________________________________________________________________
# bidirectional_5 (Bidirection (None, 651, 300)          361200
# _________________________________________________________________
# time_distributed_5 (TimeDist (None, 651, 5)            1505
# _________________________________________________________________
# crf_5 (CRF)                  (None, 651, 5)            65
# =================================================================
# Total params: 3,142,720
# Trainable params: 3,142,720
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2000 samples, validate on 1000 samples
# Epoch 1/100
# 2000/2000 [==============================] - 41s 21ms/step - loss: 1.4166 - crf_viterbi_accuracy: 0.3167 - accuracy: 0.0333 - val_loss: 0.6296 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 2/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.5485 - crf_viterbi_accuracy: 0.9179 - accuracy: 0.0333 - val_loss: 0.4566 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 3/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.4843 - crf_viterbi_accuracy: 0.9180 - accuracy: 0.0333 - val_loss: 0.4318 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 4/100
# 2000/2000 [==============================] - 40s 20ms/step - loss: 0.4558 - crf_viterbi_accuracy: 0.9180 - accuracy: 0.0333 - val_loss: 0.4060 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 5/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.4147 - crf_viterbi_accuracy: 0.9180 - accuracy: 0.0333 - val_loss: 0.3597 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 6/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.3414 - crf_viterbi_accuracy: 0.9182 - accuracy: 0.0333 - val_loss: 0.2914 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 7/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.2589 - crf_viterbi_accuracy: 0.9217 - accuracy: 0.0333 - val_loss: 0.2341 - val_crf_viterbi_accuracy: 0.9270 - val_accuracy: 0.9270
# Epoch 8/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.1947 - crf_viterbi_accuracy: 0.9315 - accuracy: 0.0333 - val_loss: 0.2042 - val_crf_viterbi_accuracy: 0.9360 - val_accuracy: 0.9360
# Epoch 9/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.1591 - crf_viterbi_accuracy: 0.9433 - accuracy: 0.0333 - val_loss: 0.1943 - val_crf_viterbi_accuracy: 0.9383 - val_accuracy: 0.9383
# Epoch 10/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.1422 - crf_viterbi_accuracy: 0.9471 - accuracy: 0.0333 - val_loss: 0.1918 - val_crf_viterbi_accuracy: 0.9386 - val_accuracy: 0.9386
# Epoch 11/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.1339 - crf_viterbi_accuracy: 0.9476 - accuracy: 0.0333 - val_loss: 0.1912 - val_crf_viterbi_accuracy: 0.9384 - val_accuracy: 0.9384
# Epoch 12/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.1279 - crf_viterbi_accuracy: 0.9477 - accuracy: 0.0333 - val_loss: 0.1923 - val_crf_viterbi_accuracy: 0.9387 - val_accuracy: 0.9387
# Epoch 13/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.1225 - crf_viterbi_accuracy: 0.9479 - accuracy: 0.0333 - val_loss: 0.1931 - val_crf_viterbi_accuracy: 0.9389 - val_accuracy: 0.9389
# Epoch 14/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.1174 - crf_viterbi_accuracy: 0.9491 - accuracy: 0.0333 - val_loss: 0.1934 - val_crf_viterbi_accuracy: 0.9404 - val_accuracy: 0.9404
# Epoch 15/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.1125 - crf_viterbi_accuracy: 0.9521 - accuracy: 0.0333 - val_loss: 0.1935 - val_crf_viterbi_accuracy: 0.9425 - val_accuracy: 0.9425
# Epoch 16/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.
100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.1369 - crf_viterbi_accuracy: 0.9410 - accuracy: 0.0330 - val_loss: 0.2152 - val_crf_viterbi_accuracy: 0.9402 - val_accuracy: 0.9402
# Epoch 12/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.1319 - crf_viterbi_accuracy: 0.9435 - accuracy: 0.0330 - val_loss: 0.2192 - val_crf_viterbi_accuracy: 0.9406 - val_accuracy: 0.9406
# Epoch 13/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.1292 - crf_viterbi_accuracy: 0.9451 - accuracy: 0.0330 - val_loss: 0.2237 - val_crf_viterbi_accuracy: 0.9399 - val_accuracy: 0.9399
# Epoch 14/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.1264 - crf_viterbi_accuracy: 0.9456 - accuracy: 0.0330 - val_loss: 0.2258 - val_crf_viterbi_accuracy: 0.9397 - val_accuracy: 0.9397
# Epoch 15/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.1241 - crf_viterbi_accuracy: 0.9458 - accuracy: 0.0330 - val_loss: 0.2266 - val_crf_viterbi_accuracy: 0.9396 - val_accuracy: 0.9396
# Epoch 16/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.1219 - crf_viterbi_accuracy: 0.9459 - accuracy: 0.0330 - val_loss: 0.2294 - val_crf_viterbi_accuracy: 0.9392 - val_accuracy: 0.9392
# Epoch 17/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.1196 - crf_viterbi_accuracy: 0.9461 - accuracy: 0.0330 - val_loss: 0.2307 - val_crf_viterbi_accuracy: 0.9385 - val_accuracy: 0.9385
# Epoch 18/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.1176 - crf_viterbi_accuracy: 0.9461 - accuracy: 0.0330 - val_loss: 0.2317 - val_crf_viterbi_accuracy: 0.9378 - val_accuracy: 0.9378
# Epoch 19/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.1155 - crf_viterbi_accuracy: 0.9654 - accuracy: 0.0330 - val_loss: 0.2328 - val_crf_viterbi_accuracy: 0.9543 - val_accuracy: 0.9543
# Epoch 20/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.1108 - crf_viterbi_accuracy: 0.9722 - accuracy: 0.0330 - val_loss: 0.2365 - val_crf_viterbi_accuracy: 0.9599 - val_accuracy: 0.9599
# 1000/1000 [==============================] - 19s 19ms/step
# F1-score: 20.7%
# Classification Report:
# ,precision,recall,f1-score,support
# Chemical,0.5871559633027523,0.0031530200019706375,0.00627235752437889,20298.0
# Disease,0.2485026513561973,0.3816275118636124,0.30100272630654773,17069.0
# micro avg,0.24990502241471013,0.1760376803061525,0.2065662830316067,37367.0
# macro avg,0.4178293073294748,0.19239026593279152,0.1536375419154633,37367.0
# weighted avg,0.43246135625333043,0.1760376803061525,0.1409032528261917,37367.0
#
# !!!!!! Starting model number 4 !!!!!!
# Points in X_train after augmentation: 2000
# Points in y_train after augmentation: 2000
# /usr/local/lib/python3.7/dist-packages/keras_contrib/layers/crf.py:346: UserWarning: CRF.loss_function is deprecated and it might be removed in the future. Please use losses.crf_loss instead.
#   warnings.warn('CRF.loss_function is deprecated '
# /usr/local/lib/python3.7/dist-packages/keras_contrib/layers/crf.py:353: UserWarning: CRF.accuracy is deprecated and it might be removed in the future. Please use metrics.crf_accuracy
#   warnings.warn('CRF.accuracy is deprecated and it '
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         (None, 651)               0
# _________________________________________________________________
# embedding_8 (Embedding)      (None, 651, 150)          2779950
# _________________________________________________________________
# bidirectional_8 (Bidirection (None, 651, 300)          361200
# _________________________________________________________________
# time_distributed_8 (TimeDist (None, 651, 5)            1505
# _________________________________________________________________
# crf_8 (CRF)                  (None, 651, 5)            65
# =================================================================
# Total params: 3,142,720
# Trainable params: 3,142,720
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2000 samples, validate on 1000 samples
# Epoch 1/100
# 2000/2000 [==============================] - 42s 21ms/step - loss: 1.6715 - crf_viterbi_accuracy: 0.3043 - accuracy: 0.0331 - val_loss: 0.5293 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 2/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.4688 - crf_viterbi_accuracy: 0.9182 - accuracy: 0.0331 - val_loss: 0.3885 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 3/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.4086 - crf_viterbi_accuracy: 0.9182 - accuracy: 0.0331 - val_loss: 0.3637 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 4/100
# 2000/2000 [==============================] - 40s 20ms/step - loss: 0.3933 - crf_viterbi_accuracy: 0.9182 - accuracy: 0.0331 - val_loss: 0.3532 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 5/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.3753 - crf_viterbi_accuracy: 0.9182 - accuracy: 0.0331 - val_loss: 0.3350 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 6/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.3450 - crf_viterbi_accuracy: 0.9182 - accuracy: 0.0331 - val_loss: 0.3058 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 7/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.2974 - crf_viterbi_accuracy: 0.9183 - accuracy: 0.0331 - val_loss: 0.2653 - val_crf_viterbi_accuracy: 0.9258 - val_accuracy: 0.9258
# Epoch 8/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0
100
# 2000/2000 [==============================] - 40s 20ms/step - loss: 0.0888 - crf_viterbi_accuracy: 0.9750 - accuracy: 0.0331 - val_loss: 0.1813 - val_crf_viterbi_accuracy: 0.9572 - val_accuracy: 0.9572
# Epoch 19/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.0842 - crf_viterbi_accuracy: 0.9771 - accuracy: 0.0331 - val_loss: 0.1805 - val_crf_viterbi_accuracy: 0.9578 - val_accuracy: 0.9578
# Epoch 20/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.0799 - crf_viterbi_accuracy: 0.9788 - accuracy: 0.0331 - val_loss: 0.1807 - val_crf_viterbi_accuracy: 0.9596 - val_accuracy: 0.9596
# Epoch 21/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.0758 - crf_viterbi_accuracy: 0.9806 - accuracy: 0.0331 - val_loss: 0.1797 - val_crf_viterbi_accuracy: 0.9595 - val_accuracy: 0.9595
# Epoch 22/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.0717 - crf_viterbi_accuracy: 0.9823 - accuracy: 0.0331 - val_loss: 0.1789 - val_crf_viterbi_accuracy: 0.9602 - val_accuracy: 0.9602
# Epoch 23/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.0682 - crf_viterbi_accuracy: 0.9839 - accuracy: 0.0331 - val_loss: 0.1793 - val_crf_viterbi_accuracy: 0.9609 - val_accuracy: 0.9609
# Epoch 24/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.0652 - crf_viterbi_accuracy: 0.9847 - accuracy: 0.0331 - val_loss: 0.1787 - val_crf_viterbi_accuracy: 0.9609 - val_accuracy: 0.9609
# Epoch 25/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.0622 - crf_viterbi_accuracy: 0.9857 - accuracy: 0.0331 - val_loss: 0.1795 - val_crf_viterbi_accuracy: 0.9609 - val_accuracy: 0.9609
# Epoch 26/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.0599 - crf_viterbi_accuracy: 0.9863 - accuracy: 0.0331 - val_loss: 0.1805 - val_crf_viterbi_accuracy: 0.9606 - val_accuracy: 0.9606
# Epoch 27/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.0576 - crf_viterbi_accuracy: 0.9868 - accuracy: 0.0331 - val_loss: 0.1827 - val_crf_viterbi_accuracy: 0.9615 - val_accuracy: 0.9615
# Epoch 28/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.0553 - crf_viterbi_accuracy: 0.9874 - accuracy: 0.0331 - val_loss: 0.1826 - val_crf_viterbi_accuracy: 0.9607 - val_accuracy: 0.9607
# Epoch 29/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.0533 - crf_viterbi_accuracy: 0.9879 - accuracy: 0.0331 - val_loss: 0.1828 - val_crf_viterbi_accuracy: 0.9597 - val_accuracy: 0.9597
# Epoch 30/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.0507 - crf_viterbi_accuracy: 0.9883 - accuracy: 0.0331 - val_loss: 0.1882 - val_crf_viterbi_accuracy: 0.9608 - val_accuracy: 0.9608
# Epoch 31/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.0483 - crf_viterbi_accuracy: 0.9886 - accuracy: 0.0331 - val_loss: 0.1904 - val_crf_viterbi_accuracy: 0.9600 - val_accuracy: 0.9600
# Epoch 32/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.0462 - crf_viterbi_accuracy: 0.9890 - accuracy: 0.0331 - val_loss: 0.1912 - val_crf_viterbi_accuracy: 0.9593 - val_accuracy: 0.9593
# Epoch 33/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.0445 - crf_viterbi_accuracy: 0.9895 - accuracy: 0.0331 - val_loss: 0.1940 - val_crf_viterbi_accuracy: 0.9614 - val_accuracy: 0.9614
# Epoch 34/100
# 2000/2000 [==============================] - 40s 20ms/step - loss: 0.0427 - crf_viterbi_accuracy: 0.9897 - accuracy: 0.0331 - val_loss: 0.1951 - val_crf_viterbi_accuracy: 0.9616 - val_accuracy: 0.9616
# 1000/1000 [==============================] - 19s 19ms/step
# F1-score: 66.9%
# Classification Report:
# ,precision,recall,f1-score,support
# Chemical,0
100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.1140 - crf_viterbi_accuracy: 0.9589 - accuracy: 0.0330 - val_loss: 0.1960 - val_crf_viterbi_accuracy: 0.9470 - val_accuracy: 0.9470
# Epoch 19/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.1088 - crf_viterbi_accuracy: 0.9626 - accuracy: 0.0330 - val_loss: 0.1965 - val_crf_viterbi_accuracy: 0.9508 - val_accuracy: 0.9508
# Epoch 20/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.1024 - crf_viterbi_accuracy: 0.9681 - accuracy: 0.0330 - val_loss: 0.1945 - val_crf_viterbi_accuracy: 0.9548 - val_accuracy: 0.9548
# Epoch 21/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.0946 - crf_viterbi_accuracy: 0.9724 - accuracy: 0.0330 - val_loss: 0.1890 - val_crf_viterbi_accuracy: 0.9560 - val_accuracy: 0.9560
# Epoch 22/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.0867 - crf_viterbi_accuracy: 0.9756 - accuracy: 0.0330 - val_loss: 0.1864 - val_crf_viterbi_accuracy: 0.9576 - val_accuracy: 0.9576
# Epoch 23/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.0803 - crf_viterbi_accuracy: 0.9773 - accuracy: 0.0330 - val_loss: 0.1833 - val_crf_viterbi_accuracy: 0.9581 - val_accuracy: 0.9581
# Epoch 24/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.0758 - crf_viterbi_accuracy: 0.9784 - accuracy: 0.0330 - val_loss: 0.1819 - val_crf_viterbi_accuracy: 0.9589 - val_accuracy: 0.9589
# Epoch 25/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.0719 - crf_viterbi_accuracy: 0.9791 - accuracy: 0.0330 - val_loss: 0.1817 - val_crf_viterbi_accuracy: 0.9593 - val_accuracy: 0.9593
# Epoch 26/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.0687 - crf_viterbi_accuracy: 0.9800 - accuracy: 0.0330 - val_loss: 0.1839 - val_crf_viterbi_accuracy: 0.9600 - val_accuracy: 0.9600
# Epoch 27/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.0661 - crf_viterbi_accuracy: 0.9805 - accuracy: 0.0330 - val_loss: 0.1841 - val_crf_viterbi_accuracy: 0.9599 - val_accuracy: 0.9599
# Epoch 28/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.0636 - crf_viterbi_accuracy: 0.9812 - accuracy: 0.0330 - val_loss: 0.1831 - val_crf_viterbi_accuracy: 0.9598 - val_accuracy: 0.9598
# Epoch 29/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.0616 - crf_viterbi_accuracy: 0.9817 - accuracy: 0.0330 - val_loss: 0.1880 - val_crf_viterbi_accuracy: 0.9601 - val_accuracy: 0.9601
# Epoch 30/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.0597 - crf_viterbi_accuracy: 0.9821 - accuracy: 0.0330 - val_loss: 0.1853 - val_crf_viterbi_accuracy: 0.9601 - val_accuracy: 0.9601
# Epoch 31/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.0578 - crf_viterbi_accuracy: 0.9826 - accuracy: 0.0330 - val_loss: 0.1899 - val_crf_viterbi_accuracy: 0.9599 - val_accuracy: 0.9599
# Epoch 32/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.0562 - crf_viterbi_accuracy: 0.9830 - accuracy: 0.0330 - val_loss: 0.1897 - val_crf_viterbi_accuracy: 0.9602 - val_accuracy: 0.9602
# Epoch 33/100
# ...
# Epoch 58/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.1779 - crf_viterbi_accuracy: 0.9860 - accuracy: 0.0331 - val_loss: 0.2844 - val_crf_viterbi_accuracy: 0.9610 - val_accuracy: 0.9610
# Epoch 59/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.1721 - crf_viterbi_accuracy: 0.9864 - accuracy: 0.0331 - val_loss: 0.2779 - val_crf_viterbi_accuracy: 0.9619 - val_accuracy: 0.9619
# Epoch 60/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.1668 - crf_viterbi_accuracy: 0.9868 - accuracy: 0.0331 - val_loss: 0.2797 - val_crf_viterbi_accuracy: 0.9612 - val_accuracy: 0.9612
# Epoch 61/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.1619 - crf_viterbi_accuracy: 0.9870 - accuracy: 0.0331 - val_loss: 0.2753 - val_crf_viterbi_accuracy: 0.9613 - val_accuracy: 0.9613
# Epoch 62/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.1572 - crf_viterbi_accuracy: 0.9872 - accuracy: 0.0331 - val_loss: 0.2723 - val_crf_viterbi_accuracy: 0.9612 - val_accuracy: 0.9612
# Epoch 63/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.1530 - crf_viterbi_accuracy: 0.9874 - accuracy: 0.0331 - val_loss: 0.2730 - val_crf_viterbi_accuracy: 0.9608 - val_accuracy: 0.9608
# Epoch 64/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.1486 - crf_viterbi_accuracy: 0.9877 - accuracy: 0.0331 - val_loss: 0.2693 - val_crf_viterbi_accuracy: 0.9608 - val_accuracy: 0.9608
# Epoch 65/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.1449 - crf_viterbi_accuracy: 0.9879 - accuracy: 0.0331 - val_loss: 0.2692 - val_crf_viterbi_accuracy: 0.9600 - val_accuracy: 0.9600
# Epoch 66/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.1412 - crf_viterbi_accuracy: 0.9880 - accuracy: 0.0331 - val_loss: 0.2688 - val_crf_viterbi_accuracy: 0.9596 - val_accuracy: 0.9596
# Epoch 67/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.1377 - crf_viterbi_accuracy: 0.9882 - accuracy: 0.0331 - val_loss: 0.2641 - val_crf_viterbi_accuracy: 0.9598 - val_accuracy: 0.9598
# Epoch 68/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.1342 - crf_viterbi_accuracy: 0.9891 - accuracy: 0.0331 - val_loss: 0.2630 - val_crf_viterbi_accuracy: 0.9604 - val_accuracy: 0.9604
# Epoch 69/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.1311 - crf_viterbi_accuracy: 0.9896 - accuracy: 0.0331 - val_loss: 0.2625 - val_crf_viterbi_accuracy: 0.9592 - val_accuracy: 0.9592
# Epoch 70/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.1277 - crf_viterbi_accuracy: 0.9899 - accuracy: 0.0331 - val_loss: 0.2577 - val_crf_viterbi_accuracy: 0.9606 - val_accuracy: 0.9606
# Epoch 71/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.1248 - crf_viterbi_accuracy: 0.9900 - accuracy: 0.0331 - val_loss: 0.2554 - val_crf_viterbi_accuracy: 0.9605 - val_accuracy: 0.9605
# Epoch 72/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.1219 - crf_viterbi_accuracy: 0.9901 - accuracy: 0.0331 - val_loss: 0.2620 - val_crf_viterbi_accuracy: 0.9584 - val_accuracy: 0.9584
# Epoch 73/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.1191 - crf_viterbi_accuracy: 0.9904 - accuracy: 0.0331 - val_loss: 0.2577 - val_crf_viterbi_accuracy: 0.9600 - val_accuracy: 0.9600
# Epoch 74/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.1164 - crf_viterbi_accuracy: 0.9911 - accuracy: 0.0331 - val_loss: 0.2609 - val_crf_viterbi_accuracy: 0.9587 - val_accuracy: 0.9587
# Epoch 75/100
# 2000/2000 [==============================] - 38s 19ms/step - loss: 0.1138 - crf_viterbi_accuracy: 0.9913 - accuracy: 0.0331 - val_loss: 0.2496 - val_crf_viterbi_accuracy: 0.9601 - val_accuracy: 0.9601
# Epoch 76/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.1111 - crf_viterbi_accuracy: 0.9917 - accuracy: 0.0331 - val_loss: 0.2609 - val_crf_viterbi_accuracy: 0.9573 - val_accuracy: 0.9573
# Epoch 77/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.1085 - crf_viterbi_accuracy: 0.9923 - accuracy: 0.0331 - val_loss: 0.2470 - val_crf_viterbi_accuracy: 0.9596 - val_accuracy: 0.9596
# Epoch 78/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.1055 - crf_viterbi_accuracy: 0.9934 - accuracy: 0.0331 - val_loss: 0.2517 - val_crf_viterbi_accuracy: 0.9585 - val_accuracy: 0.9585
# Epoch 79/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.1012 - crf_viterbi_accuracy: 0.9947 - accuracy: 0.0331 - val_loss: 0.2471 - val_crf_viterbi_accuracy: 0.9584 - val_accuracy: 0.9584
# Epoch 80/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.0855 - crf_viterbi_accuracy: 0.9951 - accuracy: 0.0331 - val_loss: 0.2357 - val_crf_viterbi_accuracy: 0.9569 - val_accuracy: 0.9569
# Epoch 81/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.0484 - crf_viterbi_accuracy: 0.9950 - accuracy: 0.0331 - val_loss: 0.2447 - val_crf_viterbi_accuracy: 0.9561 - val_accuracy: 0.9561
# Epoch 82/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.0233 - crf_viterbi_accuracy: 0.9956 - accuracy: 0.0331 - val_loss: 0.2539 - val_crf_viterbi_accuracy: 0.9565 - val_accuracy: 0.9565
# Epoch 83/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.0150 - crf_viterbi_accuracy: 0.9966 - accuracy: 0.0331 - val_loss: 0.2586 - val_crf_viterbi_accuracy: 0.9562 - val_accuracy: 0.9562
# Epoch 84/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.0121 - crf_viterbi_accuracy: 0.9969 - accuracy: 0.0331 - val_loss: 0.2632 - val_crf_viterbi_accuracy: 0.9571 - val_accuracy: 0.9571
# Epoch 85/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.0100 - crf_viterbi_accuracy: 0.9973 - accuracy: 0.0331 - val_loss: 0.2727 - val_crf_viterbi_accuracy: 0.9560 - val_accuracy: 0.9560
# Epoch 86/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.0089 - crf_viterbi_accuracy: 0.9974 - accuracy: 0.0331 - val_loss: 0.2725 - val_crf_viterbi_accuracy: 0.9545 - val_accuracy: 0.9545
# Epoch 87/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.0080 - crf_viterbi_accuracy: 0.9976 - accuracy: 0.0331 - val_loss: 0.2802 - val_crf_viterbi_accuracy: 0.9539 - val_accuracy: 0.9539
# Epoch 88/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.0074 - crf_viterbi_accuracy: 0.9976 - accuracy: 0.0331 - val_loss: 0.2698 - val_crf_viterbi_accuracy: 0.9585 - val_accuracy: 0.9585
# Epoch 89/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.0067 - crf_viterbi_accuracy: 0.9978 - accuracy: 0.0331 - val_loss: 0.2834 - val_crf_viterbi_accuracy: 0.9546 - val_accuracy: 0.9546
# Epoch 90/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.0060 - crf_viterbi_accuracy: 0.9978 - accuracy: 0.0331 - val_loss: 0.2808 - val_crf_viterbi_accuracy: 0.9550 - val_accuracy: 0.9550
# 1000/1000 [==============================] - 20s 20ms/step
# F1-score: 65.1%
# Classification Report:
# ,precision,recall,f1-score,support
# Chemical,0.7698768197088466,0.6096659769435412,0.6804684922467832,20298.0
# Disease,0.6326530612244898,0.6047805964028355,0.618402923381058,17069.0
# micro avg,0.7007502083912198,0.6074343672224155,0.6507640700708164,37367.0
# macro avg,0.7012649404666682,0.6072232866731884,0.6494357078139206,37367.0
# weighted avg,0.7071939087561481,0.6074343672224155,0.6521173483238281,37367.0
#
# !!!!!! Starting model number 10 !!!!!!
# Points in X_train after augmentation: 2000
# Points in y_train after augmentation: 2000
# /usr/local/lib/python3.7/dist-packages/keras_contrib/layers/crf.py:346: UserWarning: CRF.loss_function is deprecated and it might be removed in the future. Please use losses.crf_loss instead.
#   warnings.warn('CRF.loss_function is deprecated '
# /usr/local/lib/python3.7/dist-packages/keras_contrib/layers/crf.py:353: UserWarning: CRF.accuracy is deprecated and it might be removed in the future. Please use metrics.crf_accuracy
#   warnings.warn('CRF.accuracy is deprecated and it '
# Model: "model_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input
100
# 2000/2000 [==============================] - 40s 20ms/step - loss: 0.0914 - crf_viterbi_accuracy: 0.9728 - accuracy: 0.0335 - val_loss: 0.1853 - val_crf_viterbi_accuracy: 0.9559 - val_accuracy: 0.9559
# Epoch 20/100
# 2000/2000 [==============================] - 40s 20ms/step - loss: 0.0850 - crf_viterbi_accuracy: 0.9736 - accuracy: 0.0335 - val_loss: 0.1859 - val_crf_viterbi_accuracy: 0.9562 - val_accuracy: 0.9562
# Epoch 21/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.0800 - crf_viterbi_accuracy: 0.9742 - accuracy: 0.0335 - val_loss: 0.1865 - val_crf_viterbi_accuracy: 0.9563 - val_accuracy: 0.9563
# Epoch 22/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.0756 - crf_viterbi_accuracy: 0.9745 - accuracy: 0.0335 - val_loss: 0.1896 - val_crf_viterbi_accuracy: 0.9568 - val_accuracy: 0.9568
# Epoch 23/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.0718 - crf_viterbi_accuracy: 0.9748 - accuracy: 0.0335 - val_loss: 0.1872 - val_crf_viterbi_accuracy: 0.9563 - val_accuracy: 0.9563
# Epoch 24/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.0685 - crf_viterbi_accuracy: 0.9751 - accuracy: 0.0335 - val_loss: 0.1892 - val_crf_viterbi_accuracy: 0.9567 - val_accuracy: 0.9567
# Epoch 25/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.0654 - crf_viterbi_accuracy: 0.9753 - accuracy: 0.0335 - val_loss: 0.1901 - val_crf_viterbi_accuracy: 0.9562 - val_accuracy: 0.9562
# Epoch 26/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.0623 - crf_viterbi_accuracy: 0.9763 - accuracy: 0.0335 - val_loss: 0.1914 - val_crf_viterbi_accuracy: 0.9573 - val_accuracy: 0.9573
# Epoch 27/100
# 2000/2000 [==============================] - 39s 20ms/step - loss: 0.0592 - crf_viterbi_accuracy: 0.9788 - accuracy: 0.0335 - val_loss: 0.1897 - val_crf_viterbi_accuracy: 0.9585 - val_accuracy: 0.9585
# Epoch 28/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.0558 - crf_viterbi_accuracy: 0.9813 - accuracy: 0.0335 - val_loss: 0.1904 - val_crf_viterbi_accuracy: 0.9589 - val_accuracy: 0.9589
# Epoch 29/100
# 2000/2000 [==============================] - 39s 19ms/step - loss: 0.0524 - crf_viterbi_accuracy: 0.9828 - accuracy: 0.0335 - val_loss: 0.1925 - val_crf_viterbi_accuracy: 0.9590 - val_accuracy: 0.9590
# 1000/1000 [==============================] - 20s 20ms/step
# F1-score: 55.5%
# Classification Report:
# ,precision,recall,f1-score,support
# Chemical,0.77610602471349,0.597201694748251,0.6750006960492246,20298.0
# Disease,0.4165000810416554,0.45163747143945165,0.43335769295632137,17069.0
# micro avg,0.5810771214252227,0.5307089142826559,0.5547520805650745,37367.0
# macro avg,0.5963030528775727,0.5244195830938514,0.554179194502773,37367.0
# weighted avg,0.6118403932061561,0.5307089142826559,0.5646197604698961,37367.0

# %%
number_of_training_models = 10
target_augmented_percentage = 5

print(f"!!!!!! Augmented Percentage {target_augmented_percentage*100}% !!!!!!")

for i in range(number_of_training_models):
  print(f"!!!!!! Starting model number {i+1} !!!!!!")
  create_train_and_validate_model(target_augmented_percentage)

# %%
number_of_training_models = 10
target_augmented_percentage = 10

print(f"!!!!!! Augmented Percentage {target_augmented_percentage*100}% !!!!!!")

for i in range(number_of_training_models):
  print(f"!!!!!! Starting model number {i+1} !!!!!!")
  create_train_and_validate_model(target_augmented_percentage)
# Out:
# !!!!!! Augmented Percentage 1000% !!!!!!
# !!!!!! Starting model number 1 !!!!!!
# Points in X_train after augmentation: 5500
# Points in y_train after augmentation: 5500
# /usr/local/lib/python3.7/dist-packages/keras_contrib/layers/crf.py:346: UserWarning: CRF.loss_function is deprecated and it might be removed in the future. Please use losses.crf_loss instead.
#   warnings.warn('CRF.loss_function is deprecated '
# /usr/local/lib/python3.7/dist-packages/keras_contrib/layers/crf.py:353: UserWarning: CRF.accuracy is deprecated and it might be removed in the future. Please use metrics.crf_accuracy
#   warnings.warn('CRF.accuracy is deprecated and it '
# Model: "model_36"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_36 (InputLayer)        (None, 651)               0
# _________________________________________________________________
# embedding_36 (Embedding)     (None, 651, 150)          2779950
# _________________________________________________________________
# bidirectional_36 (Bidirectio (None, 651, 300)          362400
# _________________________________________________________________
# cu_dnnlstm_72 (CuDNNLSTM)    (None, 651, 300)          722400
# _________________________________________________________________
# time_distributed_36 (TimeDis (None, 651, 5)            1505
# _________________________________________________________________
# crf_36 (CRF)                 (None, 651, 5)            65
# =================================================================
# Total params: 3,866,320
# Trainable params: 3,866,320
# Non-trainable params: 0
# _________________________________________________________________
# (1000, 651)
# 1000
# Train on 5500 samples, validate on 1000 samples
# Epoch 1/100
# 5500/5500 [==============================] - 48s 9ms/step - loss: 0.4727 - crf_viterbi_accuracy: 0.8828 - accuracy: 0.0122 - val_loss: 0.3558 - val_crf_viterbi_accuracy: 0.9257 - val_accuracy: 0.9257
# Epoch 2/100
# 5500/5500 [==============================] - 43s 8ms/step - loss: 0.2471 - crf_viterbi_accuracy: 0.9314 - accuracy: 0.0122 - val_loss: 0.2657 - val_crf_viterbi_accuracy: 0.9310 - val_accuracy: 0.9310
# Epoch 3/100
# 5500/5500 [==============================] - 44s 8ms/step - loss: 0.1379 - crf_viterbi_accuracy: 0.9458 - accuracy: 0.0122 - val_loss: 0.2729 - val_crf_viterbi_accuracy: 0.9368 - val_accuracy: 0.9368
# Epoch 4/100
# 5500/5500 [==============================] - 44s 8ms/step - loss: 0.1132 - crf_viterbi_accuracy: 0.9641 - accuracy: 0.0122 - val_loss: 0.2853 - val_crf_viterbi_accuracy: 0.9419 - val_accuracy: 0.9419
# Epoch 5/100
# 5500/5500 [==============================] - 43s 8ms/step - loss: 0.0939 - crf_viterbi_accuracy: 0.9686 - accuracy: 0.0122 - val_loss: 0.3220 - val_crf_viterbi_accuracy: 0.9424 - val_accuracy: 0.9424
# Epoch 6/100
# 5500/5500 [==============================] - 43s 8ms/step - loss: 0.0785 - crf_viterbi_accuracy: 0.9700 - accuracy: 0.0122 - val_loss: 0.3356 - val_crf_viterbi_accuracy: 0.9413 - val_accuracy: 0.9413
# Epoch 7/100
# 5500/5500 [==============================] - 44s 8ms/step - loss: 0.0727 - crf_viterbi_accuracy: 0.9739 - accuracy: 0.0122 - val_loss: 0.3172 - val_crf_viterbi_accuracy: 0.9460 - val_accuracy: 0.9460
# 1000/1000 [==============================] - 13s 13ms/step
# F1-score: 21.5%
# Classification Report:
# ,precision,recall,f1-score,support
# Chemical,0.36645351696999506,0.25692186422307617,0.30206493092762604,20298.0
# Disease,0.16533151525481507,0.05682816802390298,0.0845831880013952,17069.0
# micro avg,0.3077420638869539,0.16552037894398802,0.21526146349952147,37367.0
# macro avg,0.26589251611240505,0.15687501612348959,0.19332405946451062,37367.0
# weighted avg,0.2745823084898814,0.16552037894398802,0.20272070018906435,37367.0
#
# !!!!!! Starting model number 2 !!!!!!
# Points in X_train after augmentation: 5500
# Points in y_train after augmentation: 5500
# /usr/local/lib/python3.7/dist-packages/keras_contrib/layers/crf.py:346: UserWarning: CRF.loss_function is deprecated and it might be removed in the future. Please use losses.crf_loss instead.
#   warnings.warn('CRF.loss_function is deprecated '
# /usr/local/lib/python3.7/dist-packages/keras_contrib/layers/crf.py:353: UserWarning: CRF.accuracy is deprecated and it might be removed in the future. Please use metrics.crf_accuracy
#   warnings.warn('CRF.accuracy is deprecated and it '
# Model: "model_37"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_37 (InputLayer)        (None, 651)               0
# _________________________________________________________________
# embedding_37 (Embedding)     (None, 651, 150)          2779950
# _________________________________________________________________
# bidirectional_37 (Bidirectio (None, 651, 300)          362400
# _________________________________________________________________
# cu_dnnlstm_74 (CuDNNLSTM)    (None, 651, 300)          722400
# _________________________________________________________________
# time_distributed_37 (TimeDis (None, 651, 5)            1505
# _________________________________________________________________
# crf_37 (CRF)                 (None, 651, 5)            65
# =================================================================
# Total params: 3,866,320
# Trainable params: 3,866,320
# Non-trainable params: 0
# _________________________________________________________________
# (1000, 651)
# 1000
# Train on 5500 samples, validate on 1000 samples
# Epoch 1/100
# 5500/5500 [==============================] - 49s 9ms/step - loss: 0.8647 - crf_viterbi_accuracy: 0.8681 - accuracy: 0.0121 - val_loss: 0.6062 - val_crf_viterbi_accuracy: 0.9245 - val_accuracy: 0.9245
# Epoch 2/100
# 5500/5500 [==============================] - 44s 8ms/step - loss: 0.3645 - crf_viterbi_accuracy: 0.9268 - accuracy: 0.0121 - val_loss: 0.2938 - val_crf_viterbi_accuracy: 0.9237 - val_accuracy: 0.9237
# Epoch 3/100
# 5500/5500 [==============================] - 44s 8ms/step - loss: 0.1391 - crf_viterbi_accuracy: 0.9396 - accuracy: 0.0121 - val_loss: 0.3617 - val_crf_viterbi_accuracy: 0.9347 - val_accuracy: 0.9347
# Epoch 4/100
# 5500/5500 [==============================] - 44s 8ms/step - loss: 0.1215 - crf_viterbi_accuracy: 0.9576 - accuracy: 0.0121 - val_loss: 0.3405 - val_crf_viterbi_accuracy: 0.9333 - val_accuracy: 0.9333
# Epoch 5/100
# 5500/5500 [==============================] - 44s 8ms/step - loss: 0.1132 - crf_viterbi_accuracy: 0.9583 - accuracy: 0.0121 - val_loss: 0.4029 - val_crf_viterbi_accuracy: 0.9343 - val_accuracy: 0.9343
# Epoch 6/100
# 5500/5500 [==============================] - 44s 8ms/step - loss: 0.1054 - crf_viterbi_accuracy: 0.9589 - accuracy: 0.0121 - val_loss: 0.4356 - val_crf_viterbi_accuracy: 0.9339 - val_accuracy: 0.9339
# Epoch 7/100
# 5500/5500 [==============================] - 44s 8ms/step - loss: 0.0999 - crf_viterbi_accuracy: 0.9594 - accuracy: 0.0121 - val_loss: 0.4202 - val_crf_viterbi_accuracy: 0.9342 - val_accuracy: 0.9342
# 1000/1000 [==============================] - 13s 13ms/step
# F1-score: 1.9%
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-71-128bce37bd7c> in <module>()
#       6 for i in range(number_of_training_models):
#       7   print(f"!!!!!! Starting model number {i+1} !!!!!!")
# ----> 8   create_train_and_validate_model(target_augmented_percentage)
#
# <ipython-input-66-0473c2e50c5c> in create_train_and_validate_model(augmented_percentage)
#      55   train(model, augmented_X_train, augmented_y_train, new_X_dev, new_y_dev)
#      56
# ---> 57   test(model, new_X_test, new_y_test)
#
# <ipython-input-52-87abc3696d8b> in test(model, X_test_df, y_test_df)
#       7
#       8   print("F1-score: {:.1%}".format(f1_score(test_labels, pred_labels)))
# ----> 9   report = classification_report(y_pred=pred_labels, y_true=test_labels, output_dict=True)
#      10   df = pd.DataFrame(report).transpose()
#      11   print("Classification Report:")
#
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py in classification_report(y_true, y_pred, digits, suffix, output_dict, mode, sample_weight, zero_division, scheme)
#     709             sample_weight=sample_weight,
#     710             zero_division=zero_division,
# --> 711             suffix=suffix
#     712         )
#     713         reporter.write('{} avg'.format(average), avg_p, avg_r, avg_f1, support)
#
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py in precision_recall_fscore_support(y_true, y_pred, average, warn_for, beta, sample_weight, zero_division, suffix)
#     137         scheme=None,
#     138         suffix=suffix,
# --> 139         extract_tp_actual_correct=extract_tp_actual_correct
#     140     )
#     141
#
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/v1.py in _precision_recall_fscore_support(y_true, y_pred, average, warn_for, beta, sample_weight, zero_division, scheme, suffix, extract_tp_actual_correct)
#     122     check_consistent_length(y_true, y_pred)
#     123
# --> 124     pred_sum, tp_sum, true_sum = extract_tp_actual_correct(y_true, y_pred, suffix, scheme)
#     125
#     126     if average == 'micro':
#
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py in extract_tp_actual_correct(y_true, y_pred, suffix, *args)
#     111         for type_name, start, end in get_entities(y_true, suffix):
#     112             entities_true[type_name].add((start, end))
# --> 113         for type_name, start, end in get_entities(y_pred, suffix):
#     114             entities_pred[type_name].add((start, end))
#     115
#
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/sequence_labeling.py in get_entities(seq, suffix)
#     187         else:
#     188             tag = chunk[0]
# --> 189             type_ = chunk[1:].split('-', maxsplit=1)[-1] or '_'
#     190
#     191         if end_of_chunk(prev_tag, tag, prev_type, type_):
#
# KeyboardInterrupt:
